# %%
import numpy as np
import torch
import time
import os

from sklearn import (linear_model, model_selection, preprocessing,
                     pipeline)
from scipy.spatial.distance import pdist

from kymatio.torch import HarmonicScattering3D

from kymatio.scattering3d.backend.torch_backend \
    import TorchBackend3D

from kymatio.scattering3d.utils \
    import generate_weighted_sum_of_gaussians

from kymatio.datasets import fetch_qm7
from kymatio.caching import get_cache_dir

import random

import pandas as pd
from ase.io import read

# %%
# Charger les données
train_energies = pd.read_csv('../data/energies/train.csv')
molecule_ids = train_energies['id'].values
energies = train_energies['energy'].values

# Initialiser les listes pour stocker toutes les positions et charges
all_positions = []
all_charges = []

# Lire tous les fichiers .xyz avec ASE
for mol_id in molecule_ids:
    xyz_path = f'../data/atoms/train/id_{mol_id}.xyz'
    atoms = read(xyz_path)
    
    # Obtenir les positions et numéros atomiques
    coords = atoms.get_positions()
    atomic_numbers = atoms.get_atomic_numbers()
    
    # Padding pour avoir une taille fixe
    max_atoms = 23  # Ajuster selon le nombre maximum d'atomes
    padded_coords = np.zeros((max_atoms, 3))
    padded_charges = np.zeros(max_atoms)
    
    n_atoms = len(coords)
    padded_coords[:n_atoms] = coords
    padded_charges[:n_atoms] = atomic_numbers
    
    all_positions.append(padded_coords)
    all_charges.append(padded_charges)

# Convertir en arrays numpy
pos = np.array(all_positions)
full_charges = np.array(all_charges)
target = energies

# Le reste du code reste identique à partir de la définition de n_molecules
n_molecules = len(pos)

# ...existing code...

# %%
"""qm7 = fetch_qm7(align=True)
pos = qm7['positions']
full_charges = qm7['charges']

n_molecules = pos.shape[0]"""

# %%
"""n_molecules_tot = len(pos)
n_molecules = 5
indices = random.sample(range(n_molecules_tot), n_molecules)

pos = pos[indices]
full_charges = full_charges[indices]"""

# %%
mask = full_charges <= 2
valence_charges = full_charges * mask

mask = np.logical_and(full_charges > 2, full_charges <= 10)
valence_charges += (full_charges - 2) * mask

mask = np.logical_and(full_charges > 10, full_charges <= 18)
valence_charges += (full_charges - 10) * mask

# %%
overlapping_precision = 1e-1
sigma = 2.0
min_dist = np.inf

for i in range(n_molecules):
    n_atoms = np.sum(full_charges[i] != 0)
    pos_i = pos[i, :n_atoms, :]
    min_dist = min(min_dist, pdist(pos_i).min())

delta = sigma * np.sqrt(-8 * np.log(overlapping_precision))
pos = pos * delta / min_dist

# %%
#M, N, O = 192, 128, 96
#M, N, O = 32, 32, 32
M, N, O = 160, 112, 80

grid = np.mgrid[-M//2:-M//2+M, -N//2:-N//2+N, -O//2:-O//2+O]
grid = np.fft.ifftshift(grid)

# %%
# J = 2
# L = 3
#J = 1
#L = 2
J = 3
L = 3
integral_powers = [0.5, 1.0, 2.0, 3.0]

scattering = HarmonicScattering3D(J=J, shape=(M, N, O),
                                  L=L, sigma_0=sigma,
                                  integral_powers=integral_powers)

# %%
use_cuda = torch.cuda.is_available()
device = torch.device("cuda" if use_cuda else "cpu")
scattering.to(device)
# Out:
# HarmonicScattering3D()

# %%
batch_size = 8
#batch_size = 16
n_batches = int(np.ceil(n_molecules / batch_size))

# %%
order_0, orders_1_and_2 = [], []
print('Computing solid harmonic scattering coefficients of '
      '{} molecules from the QM7 database on {}'.format(
        n_molecules,   "GPU" if use_cuda else "CPU"))
print('sigma: {}, L: {}, J: {}, integral powers: {}'.format(
        sigma, L, J, integral_powers))

this_time = None
last_time = None
for i in range(n_batches):
    this_time = time.time()
    if last_time is not None:
        dt = this_time - last_time
        print("Iteration {} ETA: [{:02}:{:02}:{:02}]".format(
                    i + 1, int(((n_batches - i - 1) * dt) // 3600),
                    int((((n_batches - i - 1) * dt) // 60) % 60),
                    int(((n_batches - i - 1) * dt) % 60)))
    else:
        print("Iteration {} ETA: {}".format(i + 1, '-'))
    last_time = this_time
    time.sleep(1)

    # Extract the current batch.
    start = i * batch_size
    end = min(start + batch_size, n_molecules)

    pos_batch = pos[start:end]
    full_batch = full_charges[start:end]
    val_batch = valence_charges[start:end]

    # Calculate the density map for the nuclear charges and transfer
    # to PyTorch.
    full_density_batch = generate_weighted_sum_of_gaussians(grid,
            pos_batch, full_batch, sigma)
    full_density_batch = torch.from_numpy(full_density_batch)
    full_density_batch = full_density_batch.to(device).float()

    # Compute zeroth-order, first-order, and second-order scattering
    # coefficients of the nuclear charges.
    full_order_0 = TorchBackend3D.compute_integrals(full_density_batch,
                                     integral_powers)
    full_scattering = scattering(full_density_batch)

    # Compute the map for valence charges.
    val_density_batch = generate_weighted_sum_of_gaussians(grid,
            pos_batch, val_batch, sigma)
    val_density_batch = torch.from_numpy(val_density_batch)
    val_density_batch = val_density_batch.to(device).float()

    # Compute scattering coefficients for the valence charges.
    val_order_0 = TorchBackend3D.compute_integrals(val_density_batch,
                                    integral_powers)
    val_scattering = scattering(val_density_batch)

    # Take the difference between nuclear and valence charges, then
    # compute the corresponding scattering coefficients.
    core_density_batch = full_density_batch - val_density_batch

    core_order_0 = TorchBackend3D.compute_integrals(core_density_batch,
                                     integral_powers)
    core_scattering = scattering(core_density_batch)

    # Stack the nuclear, valence, and core coefficients into arrays
    # and append them to the output.
    batch_order_0 = torch.stack(
        (full_order_0, val_order_0, core_order_0), dim=-1)
    batch_orders_1_and_2 = torch.stack(
        (full_scattering, val_scattering, core_scattering), dim=-1)

    order_0.append(batch_order_0)
    orders_1_and_2.append(batch_orders_1_and_2)
# Out:
# Computing solid harmonic scattering coefficients of 6591 molecules from the QM7 database on GPU
# sigma: 2.0, L: 3, J: 3, integral powers: [0.5, 1.0, 2.0, 3.0]
# Iteration 1 ETA: -
# Iteration 2 ETA: [04:44:38]
# Iteration 3 ETA: [04:14:01]
# Iteration 4 ETA: [04:24:00]
# Iteration 5 ETA: [04:22:19]
# Iteration 6 ETA: [04:24:10]
# Iteration 7 ETA: [04:15:05]
# Iteration 8 ETA: [04:22:10]
# Iteration 9 ETA: [04:19:19]
# Iteration 10 ETA: [04:20:12]
# Iteration 11 ETA: [04:30:59]
# Iteration 12 ETA: [04:17:41]
# Iteration 13 ETA: [04:15:05]
# Iteration 14 ETA: [04:19:45]
# Iteration 15 ETA: [04:21:36]
# Iteration 16 ETA: [04:23:58]
# Iteration 17 ETA: [04:08:31]
# Iteration 18 ETA: [04:07:09]
# Iteration 19 ETA: [04:16:20]
# Iteration 20 ETA: [04:05:53]
# Iteration 21 ETA: [04:19:18]
# Iteration 22 ETA: [04:10:17]
# Iteration 23 ETA: [04:14:44]
# Iteration 24 ETA: [04:17:33]
# Iteration 25 ETA: [04:19:24]
# Iteration 26 ETA: [04:22:05]
# Iteration 27 ETA: [04:10:19]
# Iteration 28 ETA: [04:08:46]
# Iteration 29 ETA: [04:13:32]
# Iteration 30 ETA: [04:12:12]
# Iteration 31 ETA: [04:19:46]
# Iteration 32 ETA: [04:14:26]
# Iteration 33 ETA: [04:19:11]
# Iteration 34 ETA: [04:12:54]
# Iteration 35 ETA: [04:24:32]
# Iteration 36 ETA: [04:12:58]
# Iteration 37 ETA: [04:03:25]
# Iteration 38 ETA: [04:10:00]
# Iteration 39 ETA: [04:14:23]
# Iteration 40 ETA: [04:10:30]
# Iteration 41 ETA: [04:05:45]
# Iteration 42 ETA: [04:08:33]
# Iteration 43 ETA: [04:15:02]
# Iteration 44 ETA: [04:09:31]
# Iteration 45 ETA: [04:11:44]
# Iteration 46 ETA: [04:18:37]
# Iteration 47 ETA: [04:17:33]
# Iteration 48 ETA: [04:15:52]
# Iteration 49 ETA: [04:09:35]
# Iteration 50 ETA: [04:05:28]
# Iteration 51 ETA: [04:09:39]
# Iteration 52 ETA: [04:13:26]
# Iteration 53 ETA: [04:15:12]
# Iteration 54 ETA: [04:05:01]
# Iteration 55 ETA: [03:58:51]
# Iteration 56 ETA: [04:02:33]
# Iteration 57 ETA: [04:07:55]
# Iteration 58 ETA: [04:12:57]
# Iteration 59 ETA: [04:03:14]
# Iteration 60 ETA: [04:08:00]
# Iteration 61 ETA: [04:02:02]
# Iteration 62 ETA: [04:04:06]
# Iteration 63 ETA: [04:07:50]
# Iteration 64 ETA: [04:02:17]
# Iteration 65 ETA: [04:08:11]
# Iteration 66 ETA: [03:58:40]
# Iteration 67 ETA: [04:03:07]
# Iteration 68 ETA: [04:01:42]
# Iteration 69 ETA: [03:56:57]
# Iteration 70 ETA: [03:55:47]
# Iteration 71 ETA: [03:58:25]
# Iteration 72 ETA: [03:55:55]
# Iteration 73 ETA: [04:04:30]
# Iteration 74 ETA: [04:08:01]
# Iteration 75 ETA: [03:57:13]
# Iteration 76 ETA: [04:01:19]
# Iteration 77 ETA: [03:48:14]
# Iteration 78 ETA: [04:01:56]
# Iteration 79 ETA: [03:50:44]
# Iteration 80 ETA: [04:01:18]
# Iteration 81 ETA: [03:51:34]
# Iteration 82 ETA: [03:59:25]
# Iteration 83 ETA: [03:59:13]
# Iteration 84 ETA: [03:53:32]
# Iteration 85 ETA: [04:02:01]
# Iteration 86 ETA: [03:50:56]
# Iteration 87 ETA: [03:53:17]
# Iteration 88 ETA: [04:09:28]
# Iteration 89 ETA: [03:52:40]
# Iteration 90 ETA: [03:51:45]
# Iteration 91 ETA: [04:05:01]
# Iteration 92 ETA: [03:57:06]
# Iteration 93 ETA: [03:51:10]
# Iteration 94 ETA: [03:56:26]
# Iteration 95 ETA: [03:49:16]
# Iteration 96 ETA: [03:54:15]
# Iteration 97 ETA: [03:48:53]
# Iteration 98 ETA: [03:54:42]
# Iteration 99 ETA: [03:54:33]
# Iteration 100 ETA: [03:54:14]
# Iteration 101 ETA: [03:48:06]
# Iteration 102 ETA: [03:47:22]
# Iteration 103 ETA: [03:48:36]
# Iteration 104 ETA: [03:46:52]
# Iteration 105 ETA: [03:47:49]
# Iteration 106 ETA: [03:49:43]
# Iteration 107 ETA: [03:47:50]
# Iteration 108 ETA: [03:42:27]
# Iteration 109 ETA: [03:54:56]
# Iteration 110 ETA: [03:47:42]
# Iteration 111 ETA: [03:43:45]
# Iteration 112 ETA: [03:47:36]
# Iteration 113 ETA: [03:51:31]
# Iteration 114 ETA: [03:42:28]
# Iteration 115 ETA: [03:52:12]
# Iteration 116 ETA: [03:45:13]
# Iteration 117 ETA: [03:48:40]
# Iteration 118 ETA: [03:51:08]
# Iteration 119 ETA: [03:50:13]
# Iteration 120 ETA: [03:47:59]
# Iteration 121 ETA: [03:53:03]
# Iteration 122 ETA: [03:42:42]
# Iteration 123 ETA: [03:47:20]
# Iteration 124 ETA: [03:47:27]
# Iteration 125 ETA: [03:49:26]
# Iteration 126 ETA: [03:41:34]
# Iteration 127 ETA: [03:44:02]
# Iteration 128 ETA: [03:38:18]
# Iteration 129 ETA: [03:45:17]
# Iteration 130 ETA: [03:37:02]
# Iteration 131 ETA: [03:46:52]
# Iteration 132 ETA: [03:48:07]
# Iteration 133 ETA: [03:48:18]
# Iteration 134 ETA: [03:39:34]
# Iteration 135 ETA: [03:40:55]
# Iteration 136 ETA: [03:46:44]
# Iteration 137 ETA: [03:43:47]
# Iteration 138 ETA: [03:45:42]
# Iteration 139 ETA: [03:34:32]
# Iteration 140 ETA: [03:38:50]
# Iteration 141 ETA: [03:40:38]
# Iteration 142 ETA: [03:36:18]
# Iteration 143 ETA: [03:41:17]
# Iteration 144 ETA: [03:36:55]
# Iteration 145 ETA: [03:38:44]
# Iteration 146 ETA: [03:33:01]
# Iteration 147 ETA: [03:41:26]
# Iteration 148 ETA: [03:38:18]
# Iteration 149 ETA: [03:45:01]
# Iteration 150 ETA: [03:37:43]
# Iteration 151 ETA: [03:37:21]
# Iteration 152 ETA: [03:46:28]
# Iteration 153 ETA: [03:39:51]
# Iteration 154 ETA: [03:34:05]
# Iteration 155 ETA: [03:37:38]
# Iteration 156 ETA: [03:37:43]
# Iteration 157 ETA: [03:36:27]
# Iteration 158 ETA: [03:39:35]
# Iteration 159 ETA: [03:40:43]
# Iteration 160 ETA: [03:31:15]
# Iteration 161 ETA: [03:33:01]
# Iteration 162 ETA: [03:30:48]
# Iteration 163 ETA: [03:30:39]
# Iteration 164 ETA: [03:35:45]
# Iteration 165 ETA: [03:32:31]
# Iteration 166 ETA: [03:34:09]
# Iteration 167 ETA: [03:28:25]
# Iteration 168 ETA: [03:30:48]
# Iteration 169 ETA: [03:24:31]
# Iteration 170 ETA: [03:31:31]
# Iteration 171 ETA: [03:24:30]
# Iteration 172 ETA: [03:25:35]
# Iteration 173 ETA: [03:28:52]
# Iteration 174 ETA: [03:23:52]
# Iteration 175 ETA: [03:21:34]
# Iteration 176 ETA: [03:35:54]
# Iteration 177 ETA: [03:21:11]
# Iteration 178 ETA: [03:31:21]
# Iteration 179 ETA: [03:32:41]
# Iteration 180 ETA: [03:22:30]
# Iteration 181 ETA: [03:21:13]
# Iteration 182 ETA: [03:25:29]
# Iteration 183 ETA: [03:18:03]
# Iteration 184 ETA: [03:29:10]
# Iteration 185 ETA: [03:23:44]
# Iteration 186 ETA: [03:18:38]
# Iteration 187 ETA: [03:22:30]
# Iteration 188 ETA: [03:23:42]
# Iteration 189 ETA: [03:20:03]
# Iteration 190 ETA: [03:19:13]
# Iteration 191 ETA: [03:22:36]
# Iteration 192 ETA: [03:31:30]
# Iteration 193 ETA: [03:19:32]
# Iteration 194 ETA: [03:18:08]
# Iteration 195 ETA: [03:26:20]
# Iteration 196 ETA: [03:18:52]
# Iteration 197 ETA: [03:24:50]
# Iteration 198 ETA: [03:21:07]
# Iteration 199 ETA: [03:16:14]
# Iteration 200 ETA: [03:23:02]
# Iteration 201 ETA: [03:15:53]
# Iteration 202 ETA: [03:23:17]
# Iteration 203 ETA: [03:22:02]
# Iteration 204 ETA: [03:14:52]
# Iteration 205 ETA: [03:15:27]
# Iteration 206 ETA: [03:18:37]
# Iteration 207 ETA: [03:15:50]
# Iteration 208 ETA: [03:17:42]
# Iteration 209 ETA: [03:15:51]
# Iteration 210 ETA: [03:13:09]
# Iteration 211 ETA: [03:15:41]
# Iteration 212 ETA: [03:12:57]
# Iteration 213 ETA: [03:15:45]
# Iteration 214 ETA: [03:19:39]
# Iteration 215 ETA: [03:20:34]
# Iteration 216 ETA: [03:14:22]
# Iteration 217 ETA: [03:17:16]
# Iteration 218 ETA: [03:12:37]
# Iteration 219 ETA: [03:16:45]
# Iteration 220 ETA: [03:14:09]
# Iteration 221 ETA: [03:12:38]
# Iteration 222 ETA: [03:05:55]
# Iteration 223 ETA: [03:11:25]
# Iteration 224 ETA: [03:20:27]
# Iteration 225 ETA: [03:15:51]
# Iteration 226 ETA: [03:12:45]
# Iteration 227 ETA: [03:01:58]
# Iteration 228 ETA: [03:14:07]
# Iteration 229 ETA: [03:07:52]
# Iteration 230 ETA: [03:19:18]
# Iteration 231 ETA: [03:14:28]
# Iteration 232 ETA: [03:11:12]
# Iteration 233 ETA: [03:04:18]
# Iteration 234 ETA: [03:09:09]
# Iteration 235 ETA: [03:07:12]
# Iteration 236 ETA: [03:06:46]
# Iteration 237 ETA: [03:09:35]
# Iteration 238 ETA: [03:11:42]
# Iteration 239 ETA: [03:09:45]
# Iteration 240 ETA: [03:09:26]
# Iteration 241 ETA: [03:07:34]
# Iteration 242 ETA: [03:03:39]
# Iteration 243 ETA: [03:04:58]
# Iteration 244 ETA: [02:59:38]
# Iteration 245 ETA: [03:02:30]
# Iteration 246 ETA: [03:07:54]
# Iteration 247 ETA: [03:01:03]
# Iteration 248 ETA: [03:07:15]
# Iteration 249 ETA: [03:02:27]
# Iteration 250 ETA: [03:04:49]
# Iteration 251 ETA: [03:06:05]
# Iteration 252 ETA: [03:09:22]
# Iteration 253 ETA: [02:58:53]
# Iteration 254 ETA: [03:03:38]
# Iteration 255 ETA: [03:01:58]
# Iteration 256 ETA: [03:02:36]
# Iteration 257 ETA: [03:03:47]
# Iteration 258 ETA: [03:03:01]
# Iteration 259 ETA: [03:06:06]
# Iteration 260 ETA: [02:58:58]
# Iteration 261 ETA: [02:58:47]
# Iteration 262 ETA: [02:59:37]
# Iteration 263 ETA: [02:57:21]
# Iteration 264 ETA: [02:59:46]
# Iteration 265 ETA: [03:02:34]
# Iteration 266 ETA: [02:58:43]
# Iteration 267 ETA: [03:02:24]
# Iteration 268 ETA: [03:01:36]
# Iteration 269 ETA: [02:57:00]
# Iteration 270 ETA: [02:59:35]
# Iteration 271 ETA: [02:53:47]
# Iteration 272 ETA: [02:57:49]
# Iteration 273 ETA: [02:58:29]
# Iteration 274 ETA: [03:00:08]
# Iteration 275 ETA: [03:02:59]
# Iteration 276 ETA: [02:57:48]
# Iteration 277 ETA: [03:04:24]
# Iteration 278 ETA: [02:52:32]
# Iteration 279 ETA: [02:55:31]
# Iteration 280 ETA: [03:00:33]
# Iteration 281 ETA: [03:00:38]
# Iteration 282 ETA: [02:50:09]
# Iteration 283 ETA: [02:52:01]
# Iteration 284 ETA: [02:56:26]
# Iteration 285 ETA: [02:51:34]
# Iteration 286 ETA: [02:54:28]
# Iteration 287 ETA: [02:56:00]
# Iteration 288 ETA: [02:55:49]
# Iteration 289 ETA: [02:51:59]
# Iteration 290 ETA: [02:43:56]
# Iteration 291 ETA: [02:50:04]
# Iteration 292 ETA: [02:50:51]
# Iteration 293 ETA: [02:55:28]
# Iteration 294 ETA: [02:50:11]
# Iteration 295 ETA: [02:54:44]
# Iteration 296 ETA: [02:56:25]
# Iteration 297 ETA: [02:50:22]
# Iteration 298 ETA: [02:44:52]
# Iteration 299 ETA: [02:54:48]
# Iteration 300 ETA: [02:57:23]
# Iteration 301 ETA: [02:55:07]
# Iteration 302 ETA: [02:47:19]
# Iteration 303 ETA: [02:46:14]
# Iteration 304 ETA: [02:48:07]
# Iteration 305 ETA: [02:55:48]
# Iteration 306 ETA: [02:49:56]
# Iteration 307 ETA: [02:50:42]
# Iteration 308 ETA: [02:48:54]
# Iteration 309 ETA: [02:50:33]
# Iteration 310 ETA: [02:46:42]
# Iteration 311 ETA: [02:48:58]
# Iteration 312 ETA: [02:43:56]
# Iteration 313 ETA: [02:51:28]
# Iteration 314 ETA: [02:43:08]
# Iteration 315 ETA: [02:45:03]
# Iteration 316 ETA: [02:44:02]
# Iteration 317 ETA: [02:46:36]
# Iteration 318 ETA: [02:44:07]
# Iteration 319 ETA: [02:44:26]
# Iteration 320 ETA: [02:41:36]
# Iteration 321 ETA: [02:39:01]
# Iteration 322 ETA: [02:46:33]
# Iteration 323 ETA: [02:50:00]
# Iteration 324 ETA: [02:44:59]
# Iteration 325 ETA: [02:48:01]
# Iteration 326 ETA: [02:34:04]
# Iteration 327 ETA: [02:41:33]
# Iteration 328 ETA: [02:36:33]
# Iteration 329 ETA: [02:45:08]
# Iteration 330 ETA: [02:41:21]
# Iteration 331 ETA: [02:33:02]
# Iteration 332 ETA: [02:38:16]
# Iteration 333 ETA: [02:42:50]
# Iteration 334 ETA: [02:44:36]
# Iteration 335 ETA: [02:38:18]
# Iteration 336 ETA: [02:38:15]
# Iteration 337 ETA: [02:31:45]
# Iteration 338 ETA: [02:39:08]
# Iteration 339 ETA: [02:31:23]
# Iteration 340 ETA: [02:45:39]
# Iteration 341 ETA: [02:33:17]
# Iteration 342 ETA: [02:33:52]
# Iteration 343 ETA: [02:35:57]
# Iteration 344 ETA: [02:31:26]
# Iteration 345 ETA: [02:33:43]
# Iteration 346 ETA: [02:38:15]
# Iteration 347 ETA: [02:31:25]
# Iteration 348 ETA: [02:33:27]
# Iteration 349 ETA: [02:35:09]
# Iteration 350 ETA: [02:32:55]
# Iteration 351 ETA: [02:35:48]
# Iteration 352 ETA: [02:34:45]
# Iteration 353 ETA: [02:38:53]
# Iteration 354 ETA: [02:29:18]
# Iteration 355 ETA: [02:34:48]
# Iteration 356 ETA: [02:32:11]
# Iteration 357 ETA: [02:34:37]
# Iteration 358 ETA: [02:37:51]
# Iteration 359 ETA: [02:29:23]
# Iteration 360 ETA: [02:26:08]
# Iteration 361 ETA: [02:34:50]
# Iteration 362 ETA: [02:31:35]
# Iteration 363 ETA: [02:28:37]
# Iteration 364 ETA: [02:29:35]
# Iteration 365 ETA: [02:27:48]
# Iteration 366 ETA: [02:27:47]
# Iteration 367 ETA: [02:30:02]
# Iteration 368 ETA: [02:29:34]
# Iteration 369 ETA: [02:20:53]
# Iteration 370 ETA: [02:31:20]
# Iteration 371 ETA: [02:29:14]
# Iteration 372 ETA: [02:31:02]
# Iteration 373 ETA: [02:31:31]
# Iteration 374 ETA: [02:24:50]
# Iteration 375 ETA: [02:26:31]
# Iteration 376 ETA: [02:25:45]
# Iteration 377 ETA: [02:23:57]
# Iteration 378 ETA: [02:23:43]
# Iteration 379 ETA: [02:28:26]
# Iteration 380 ETA: [02:25:12]
# Iteration 381 ETA: [02:24:27]
# Iteration 382 ETA: [02:25:31]
# Iteration 383 ETA: [02:20:37]
# Iteration 384 ETA: [02:22:35]
# Iteration 385 ETA: [02:19:09]
# Iteration 386 ETA: [02:25:05]
# Iteration 387 ETA: [02:22:17]
# Iteration 388 ETA: [02:16:03]
# Iteration 389 ETA: [02:20:25]
# Iteration 390 ETA: [02:16:26]
# Iteration 391 ETA: [02:16:20]
# Iteration 392 ETA: [02:14:08]
# Iteration 393 ETA: [02:15:26]
# Iteration 394 ETA: [02:16:19]
# Iteration 395 ETA: [02:14:41]
# Iteration 396 ETA: [02:20:33]
# Iteration 397 ETA: [02:19:34]
# Iteration 398 ETA: [02:17:21]
# Iteration 399 ETA: [02:19:44]
# Iteration 400 ETA: [02:19:56]
# Iteration 401 ETA: [02:21:55]
# Iteration 402 ETA: [02:11:48]
# Iteration 403 ETA: [02:20:06]
# Iteration 404 ETA: [02:16:07]
# Iteration 405 ETA: [02:18:12]
# Iteration 406 ETA: [02:13:38]
# Iteration 407 ETA: [02:17:28]
# Iteration 408 ETA: [02:14:09]
# Iteration 409 ETA: [02:19:18]
# Iteration 410 ETA: [02:12:16]
# Iteration 411 ETA: [02:17:59]
# Iteration 412 ETA: [02:08:14]
# Iteration 413 ETA: [02:14:43]
# Iteration 414 ETA: [02:15:31]
# Iteration 415 ETA: [02:13:54]
# Iteration 416 ETA: [02:07:25]
# Iteration 417 ETA: [02:11:16]
# Iteration 418 ETA: [02:12:10]
# Iteration 419 ETA: [02:10:57]
# Iteration 420 ETA: [02:13:00]
# Iteration 421 ETA: [02:08:51]
# Iteration 422 ETA: [02:14:29]
# Iteration 423 ETA: [02:14:42]
# Iteration 424 ETA: [02:09:46]
# Iteration 425 ETA: [02:10:36]
# Iteration 426 ETA: [02:09:39]
# Iteration 427 ETA: [02:01:14]
# Iteration 428 ETA: [02:06:13]
# Iteration 429 ETA: [02:09:04]
# Iteration 430 ETA: [02:04:54]
# Iteration 431 ETA: [02:06:21]
# Iteration 432 ETA: [02:07:51]
# Iteration 433 ETA: [02:09:36]
# Iteration 434 ETA: [02:06:44]
# Iteration 435 ETA: [02:07:42]
# Iteration 436 ETA: [02:05:18]
# Iteration 437 ETA: [02:03:41]
# Iteration 438 ETA: [02:04:05]
# Iteration 439 ETA: [02:02:58]
# Iteration 440 ETA: [01:58:31]
# Iteration 441 ETA: [02:06:17]
# Iteration 442 ETA: [02:04:30]
# Iteration 443 ETA: [02:02:09]
# Iteration 444 ETA: [02:00:41]
# Iteration 445 ETA: [02:04:40]
# Iteration 446 ETA: [02:06:43]
# Iteration 447 ETA: [02:02:19]
# Iteration 448 ETA: [01:59:41]
# Iteration 449 ETA: [01:58:33]
# Iteration 450 ETA: [02:01:59]
# Iteration 451 ETA: [02:03:41]
# Iteration 452 ETA: [02:01:04]
# Iteration 453 ETA: [02:03:45]
# Iteration 454 ETA: [02:04:07]
# Iteration 455 ETA: [02:01:19]
# Iteration 456 ETA: [02:04:36]
# Iteration 457 ETA: [01:59:35]
# Iteration 458 ETA: [01:57:57]
# Iteration 459 ETA: [01:59:43]
# Iteration 460 ETA: [01:59:33]
# Iteration 461 ETA: [02:01:28]
# Iteration 462 ETA: [01:57:06]
# Iteration 463 ETA: [01:56:14]
# Iteration 464 ETA: [01:57:56]
# Iteration 465 ETA: [01:56:08]
# Iteration 466 ETA: [01:58:10]
# Iteration 467 ETA: [01:53:03]
# Iteration 468 ETA: [01:57:44]
# Iteration 469 ETA: [01:56:29]
# Iteration 470 ETA: [01:51:24]
# Iteration 471 ETA: [01:55:43]
# Iteration 472 ETA: [01:54:02]
# Iteration 473 ETA: [01:52:32]
# Iteration 474 ETA: [01:57:20]
# Iteration 475 ETA: [01:51:47]
# Iteration 476 ETA: [01:53:55]
# Iteration 477 ETA: [01:53:42]
# Iteration 478 ETA: [01:52:37]
# Iteration 479 ETA: [01:50:39]
# Iteration 480 ETA: [01:55:53]
# Iteration 481 ETA: [01:46:48]
# Iteration 482 ETA: [01:53:33]
# Iteration 483 ETA: [01:52:59]
# Iteration 484 ETA: [01:47:26]
# Iteration 485 ETA: [01:52:47]
# Iteration 486 ETA: [01:49:33]
# Iteration 487 ETA: [01:49:47]
# Iteration 488 ETA: [01:50:42]
# Iteration 489 ETA: [01:48:48]
# Iteration 490 ETA: [01:52:21]
# Iteration 491 ETA: [01:49:45]
# Iteration 492 ETA: [01:45:28]
# Iteration 493 ETA: [01:48:16]
# Iteration 494 ETA: [01:43:05]
# Iteration 495 ETA: [01:43:53]
# Iteration 496 ETA: [01:48:24]
# Iteration 497 ETA: [01:46:24]
# Iteration 498 ETA: [01:43:08]
# Iteration 499 ETA: [01:46:43]
# Iteration 500 ETA: [01:45:02]
# Iteration 501 ETA: [01:47:50]
# Iteration 502 ETA: [01:42:00]
# Iteration 503 ETA: [01:44:22]
# Iteration 504 ETA: [01:44:37]
# Iteration 505 ETA: [01:39:59]
# Iteration 506 ETA: [01:43:55]
# Iteration 507 ETA: [01:39:47]
# Iteration 508 ETA: [01:47:35]
# Iteration 509 ETA: [01:42:12]
# Iteration 510 ETA: [01:43:16]
# Iteration 511 ETA: [01:43:32]
# Iteration 512 ETA: [01:43:10]
# Iteration 513 ETA: [01:44:10]
# Iteration 514 ETA: [01:41:39]
# Iteration 515 ETA: [01:42:33]
# Iteration 516 ETA: [01:41:01]
# Iteration 517 ETA: [01:40:17]
# Iteration 518 ETA: [01:40:47]
# Iteration 519 ETA: [01:35:44]
# Iteration 520 ETA: [01:36:36]
# Iteration 521 ETA: [01:38:23]
# Iteration 522 ETA: [01:37:23]
# Iteration 523 ETA: [01:40:34]
# Iteration 524 ETA: [01:34:52]
# Iteration 525 ETA: [01:34:25]
# Iteration 526 ETA: [01:39:45]
# Iteration 527 ETA: [01:35:49]
# Iteration 528 ETA: [01:37:18]
# Iteration 529 ETA: [01:39:37]
# Iteration 530 ETA: [01:33:46]
# Iteration 531 ETA: [01:36:15]
# Iteration 532 ETA: [01:32:37]
# Iteration 533 ETA: [01:32:11]
# Iteration 534 ETA: [01:32:50]
# Iteration 535 ETA: [01:32:58]
# Iteration 536 ETA: [01:32:45]
# Iteration 537 ETA: [01:34:22]
# Iteration 538 ETA: [01:31:40]
# Iteration 539 ETA: [01:33:26]
# Iteration 540 ETA: [01:35:20]
# Iteration 541 ETA: [01:35:07]
# Iteration 542 ETA: [01:33:52]
# Iteration 543 ETA: [01:30:35]
# Iteration 544 ETA: [01:30:14]
# Iteration 545 ETA: [01:32:02]
# Iteration 546 ETA: [01:31:55]
# Iteration 547 ETA: [01:27:29]
# Iteration 548 ETA: [01:29:22]
# Iteration 549 ETA: [01:33:28]
# Iteration 550 ETA: [01:32:26]
# Iteration 551 ETA: [01:27:48]
# Iteration 552 ETA: [01:27:01]
# Iteration 553 ETA: [01:26:25]
# Iteration 554 ETA: [01:27:43]
# Iteration 555 ETA: [01:28:20]
# Iteration 556 ETA: [01:27:22]
# Iteration 557 ETA: [01:27:42]
# Iteration 558 ETA: [01:22:30]
# Iteration 559 ETA: [01:25:48]
# Iteration 560 ETA: [01:23:43]
# Iteration 561 ETA: [01:22:25]
# Iteration 562 ETA: [01:26:55]
# Iteration 563 ETA: [01:28:51]
# Iteration 564 ETA: [01:24:34]
# Iteration 565 ETA: [01:23:42]
# Iteration 566 ETA: [01:24:07]
# Iteration 567 ETA: [01:26:45]
# Iteration 568 ETA: [01:23:43]
# Iteration 569 ETA: [01:23:19]
# Iteration 570 ETA: [01:24:09]
# Iteration 571 ETA: [01:18:43]
# Iteration 572 ETA: [01:23:32]
# Iteration 573 ETA: [01:22:35]
# Iteration 574 ETA: [01:21:02]
# Iteration 575 ETA: [01:21:58]
# Iteration 576 ETA: [01:19:00]
# Iteration 577 ETA: [01:18:25]
# Iteration 578 ETA: [01:21:55]
# Iteration 579 ETA: [01:17:27]
# Iteration 580 ETA: [01:21:13]
# Iteration 581 ETA: [01:22:18]
# Iteration 582 ETA: [01:17:32]
# Iteration 583 ETA: [01:20:11]
# Iteration 584 ETA: [01:16:49]
# Iteration 585 ETA: [01:16:49]
# Iteration 586 ETA: [01:15:54]
# Iteration 587 ETA: [01:15:33]
# Iteration 588 ETA: [01:17:27]
# Iteration 589 ETA: [01:15:34]
# Iteration 590 ETA: [01:16:31]
# Iteration 591 ETA: [01:13:02]
# Iteration 592 ETA: [01:16:43]
# Iteration 593 ETA: [01:14:10]
# Iteration 594 ETA: [01:17:15]
# Iteration 595 ETA: [01:15:01]
# Iteration 596 ETA: [01:13:44]
# Iteration 597 ETA: [01:13:34]
# Iteration 598 ETA: [01:14:25]
# Iteration 599 ETA: [01:12:04]
# Iteration 600 ETA: [01:13:37]
# Iteration 601 ETA: [01:15:30]
# Iteration 602 ETA: [01:13:55]
# Iteration 603 ETA: [01:12:01]
# Iteration 604 ETA: [01:11:36]
# Iteration 605 ETA: [01:09:26]
# Iteration 606 ETA: [01:08:47]
# Iteration 607 ETA: [01:10:24]
# Iteration 608 ETA: [01:10:58]
# Iteration 609 ETA: [01:10:53]
# Iteration 610 ETA: [01:10:13]
# Iteration 611 ETA: [01:08:32]
# Iteration 612 ETA: [01:10:42]
# Iteration 613 ETA: [01:08:23]
# Iteration 614 ETA: [01:06:09]
# Iteration 615 ETA: [01:08:49]
# Iteration 616 ETA: [01:07:42]
# Iteration 617 ETA: [01:08:52]
# Iteration 618 ETA: [01:08:15]
# Iteration 619 ETA: [01:08:44]
# Iteration 620 ETA: [01:06:04]
# Iteration 621 ETA: [01:05:49]
# Iteration 622 ETA: [01:05:56]
# Iteration 623 ETA: [01:07:48]
# Iteration 624 ETA: [01:05:16]
# Iteration 625 ETA: [01:05:16]
# Iteration 626 ETA: [01:06:33]
# Iteration 627 ETA: [01:04:41]
# Iteration 628 ETA: [01:03:01]
# Iteration 629 ETA: [01:04:38]
# Iteration 630 ETA: [01:02:15]
# Iteration 631 ETA: [01:02:29]
# Iteration 632 ETA: [01:02:11]
# Iteration 633 ETA: [01:01:22]
# Iteration 634 ETA: [01:00:47]
# Iteration 635 ETA: [01:02:51]
# Iteration 636 ETA: [00:58:04]
# Iteration 637 ETA: [01:01:27]
# Iteration 638 ETA: [01:00:16]
# Iteration 639 ETA: [00:59:56]
# Iteration 640 ETA: [01:00:21]
# Iteration 641 ETA: [00:59:44]
# Iteration 642 ETA: [00:59:23]
# Iteration 643 ETA: [00:59:36]
# Iteration 644 ETA: [00:58:59]
# Iteration 645 ETA: [00:56:48]
# Iteration 646 ETA: [00:59:06]
# Iteration 647 ETA: [00:57:51]
# Iteration 648 ETA: [00:56:54]
# Iteration 649 ETA: [00:56:54]
# Iteration 650 ETA: [00:55:32]
# Iteration 651 ETA: [00:54:20]
# Iteration 652 ETA: [00:57:31]
# Iteration 653 ETA: [00:55:40]
# Iteration 654 ETA: [00:55:13]
# Iteration 655 ETA: [00:55:53]
# Iteration 656 ETA: [00:55:46]
# Iteration 657 ETA: [00:55:40]
# Iteration 658 ETA: [00:55:03]
# Iteration 659 ETA: [00:56:03]
# Iteration 660 ETA: [00:53:55]
# Iteration 661 ETA: [00:52:34]
# Iteration 662 ETA: [00:53:29]
# Iteration 663 ETA: [00:52:57]
# Iteration 664 ETA: [00:54:04]
# Iteration 665 ETA: [00:50:08]
# Iteration 666 ETA: [00:50:29]
# Iteration 667 ETA: [00:50:11]
# Iteration 668 ETA: [00:49:55]
# Iteration 669 ETA: [00:50:49]
# Iteration 670 ETA: [00:51:23]
# Iteration 671 ETA: [00:50:09]
# Iteration 672 ETA: [00:49:18]
# Iteration 673 ETA: [00:49:34]
# Iteration 674 ETA: [00:48:29]
# Iteration 675 ETA: [00:47:47]
# Iteration 676 ETA: [00:47:51]
# Iteration 677 ETA: [00:48:57]
# Iteration 678 ETA: [00:45:55]
# Iteration 679 ETA: [00:47:17]
# Iteration 680 ETA: [00:47:04]
# Iteration 681 ETA: [00:44:09]
# Iteration 682 ETA: [00:47:16]
# Iteration 683 ETA: [00:45:55]
# Iteration 684 ETA: [00:45:03]
# Iteration 685 ETA: [00:43:32]
# Iteration 686 ETA: [00:43:53]
# Iteration 687 ETA: [00:45:42]
# Iteration 688 ETA: [00:44:44]
# Iteration 689 ETA: [00:43:51]
# Iteration 690 ETA: [00:43:21]
# Iteration 691 ETA: [00:44:37]
# Iteration 692 ETA: [00:43:36]
# Iteration 693 ETA: [00:42:27]
# Iteration 694 ETA: [00:43:10]
# Iteration 695 ETA: [00:41:46]
# Iteration 696 ETA: [00:42:13]
# Iteration 697 ETA: [00:41:33]
# Iteration 698 ETA: [00:40:16]
# Iteration 699 ETA: [00:40:12]
# Iteration 700 ETA: [00:39:05]
# Iteration 701 ETA: [00:39:28]
# Iteration 702 ETA: [00:39:56]
# Iteration 703 ETA: [00:39:11]
# Iteration 704 ETA: [00:38:28]
# Iteration 705 ETA: [00:38:40]
# Iteration 706 ETA: [00:38:19]
# Iteration 707 ETA: [00:38:32]
# Iteration 708 ETA: [00:36:50]
# Iteration 709 ETA: [00:37:35]
# Iteration 710 ETA: [00:37:19]
# Iteration 711 ETA: [00:36:33]
# Iteration 712 ETA: [00:37:06]
# Iteration 713 ETA: [00:35:39]
# Iteration 714 ETA: [00:35:48]
# Iteration 715 ETA: [00:36:48]
# Iteration 716 ETA: [00:36:08]
# Iteration 717 ETA: [00:34:47]
# Iteration 718 ETA: [00:34:56]
# Iteration 719 ETA: [00:33:28]
# Iteration 720 ETA: [00:33:55]
# Iteration 721 ETA: [00:33:06]
# Iteration 722 ETA: [00:34:22]
# Iteration 723 ETA: [00:31:43]
# Iteration 724 ETA: [00:32:22]
# Iteration 725 ETA: [00:31:19]
# Iteration 726 ETA: [00:32:09]
# Iteration 727 ETA: [00:31:52]
# Iteration 728 ETA: [00:30:34]
# Iteration 729 ETA: [00:29:45]
# Iteration 730 ETA: [00:32:01]
# Iteration 731 ETA: [00:30:22]
# Iteration 732 ETA: [00:30:11]
# Iteration 733 ETA: [00:30:35]
# Iteration 734 ETA: [00:29:10]
# Iteration 735 ETA: [00:28:51]
# Iteration 736 ETA: [00:28:45]
# Iteration 737 ETA: [00:27:23]
# Iteration 738 ETA: [00:28:25]
# Iteration 739 ETA: [00:27:10]
# Iteration 740 ETA: [00:26:42]
# Iteration 741 ETA: [00:27:03]
# Iteration 742 ETA: [00:25:41]
# Iteration 743 ETA: [00:26:18]
# Iteration 744 ETA: [00:25:34]
# Iteration 745 ETA: [00:25:51]
# Iteration 746 ETA: [00:25:09]
# Iteration 747 ETA: [00:25:22]
# Iteration 748 ETA: [00:24:30]
# Iteration 749 ETA: [00:24:18]
# Iteration 750 ETA: [00:24:30]
# Iteration 751 ETA: [00:24:05]
# Iteration 752 ETA: [00:23:08]
# Iteration 753 ETA: [00:22:08]
# Iteration 754 ETA: [00:22:43]
# Iteration 755 ETA: [00:22:08]
# Iteration 756 ETA: [00:22:18]
# Iteration 757 ETA: [00:21:32]
# Iteration 758 ETA: [00:21:16]
# Iteration 759 ETA: [00:20:22]
# Iteration 760 ETA: [00:20:57]
# Iteration 761 ETA: [00:20:24]
# Iteration 762 ETA: [00:20:41]
# Iteration 763 ETA: [00:19:44]
# Iteration 764 ETA: [00:19:20]
# Iteration 765 ETA: [00:19:10]
# Iteration 766 ETA: [00:18:39]
# Iteration 767 ETA: [00:18:19]
# Iteration 768 ETA: [00:18:50]
# Iteration 769 ETA: [00:18:17]
# Iteration 770 ETA: [00:17:46]
# Iteration 771 ETA: [00:17:44]
# Iteration 772 ETA: [00:17:20]
# Iteration 773 ETA: [00:17:12]
# Iteration 774 ETA: [00:16:52]
# Iteration 775 ETA: [00:15:56]
# Iteration 776 ETA: [00:15:24]
# Iteration 777 ETA: [00:15:21]
# Iteration 778 ETA: [00:14:34]
# Iteration 779 ETA: [00:14:45]
# Iteration 780 ETA: [00:13:31]
# Iteration 781 ETA: [00:13:39]
# Iteration 782 ETA: [00:13:48]
# Iteration 783 ETA: [00:13:13]
# Iteration 784 ETA: [00:12:57]
# Iteration 785 ETA: [00:12:35]
# Iteration 786 ETA: [00:11:56]
# Iteration 787 ETA: [00:12:26]
# Iteration 788 ETA: [00:11:42]
# Iteration 789 ETA: [00:10:54]
# Iteration 790 ETA: [00:10:38]
# Iteration 791 ETA: [00:10:48]
# Iteration 792 ETA: [00:10:21]
# Iteration 793 ETA: [00:10:00]
# Iteration 794 ETA: [00:09:51]
# Iteration 795 ETA: [00:09:09]
# Iteration 796 ETA: [00:09:13]
# Iteration 797 ETA: [00:08:42]
# Iteration 798 ETA: [00:08:24]
# Iteration 799 ETA: [00:07:58]
# Iteration 800 ETA: [00:07:46]
# Iteration 801 ETA: [00:07:23]
# Iteration 802 ETA: [00:07:16]
# Iteration 803 ETA: [00:06:25]
# Iteration 804 ETA: [00:06:25]
# Iteration 805 ETA: [00:06:11]
# Iteration 806 ETA: [00:05:38]
# Iteration 807 ETA: [00:05:28]
# Iteration 808 ETA: [00:05:08]
# Iteration 809 ETA: [00:04:50]
# Iteration 810 ETA: [00:04:32]
# Iteration 811 ETA: [00:04:09]
# Iteration 812 ETA: [00:03:56]
# Iteration 813 ETA: [00:03:31]
# Iteration 814 ETA: [00:03:04]
# Iteration 815 ETA: [00:02:48]
# Iteration 816 ETA: [00:02:32]
# Iteration 817 ETA: [00:02:18]
# Iteration 818 ETA: [00:01:58]
# Iteration 819 ETA: [00:01:37]
# Iteration 820 ETA: [00:01:13]
# Iteration 821 ETA: [00:00:59]
# Iteration 822 ETA: [00:00:38]
# Iteration 823 ETA: [00:00:19]
# Iteration 824 ETA: [00:00:00]

# %%
order_0 = torch.cat(order_0, dim=0)
orders_1_and_2 = torch.cat(orders_1_and_2, dim=0)

order_0 = order_0.cpu().numpy()
orders_1_and_2 = orders_1_and_2.cpu().numpy()

# %%
order_0 = order_0.reshape((n_molecules, -1))
orders_1_and_2 = orders_1_and_2.reshape((n_molecules, -1))

# %%
"""basename = 'qm7_L_{}_J_{}_sigma_{}_MNO_{}_powers_{}.npy'.format(
        L, J, sigma, (M, N, O), integral_powers)"""
basename = 'traindataset_L_{}_J_{}_sigma_{}_MNO_{}_powers_{}.npy'.format(
        L, J, sigma, (M, N, O), integral_powers)

# cache_dir = get_cache_dir("qm7/experiments")
save_dir = "save"

filename = os.path.join(save_dir, 'order_0_' + basename)
np.save(filename, order_0)

filename = os.path.join(save_dir, 'orders_1_and_2' + basename)
np.save(filename, orders_1_and_2)

# %%
scattering_coef = np.concatenate([order_0, orders_1_and_2], axis=1)

# %%
"""qm7 = fetch_qm7()
target = qm7['energies']"""

# %%
# n_folds = 5
n_folds = 3

P = np.random.permutation(n_molecules).reshape((n_folds, -1))

cross_val_folds = []

for i_fold in range(n_folds):
    fold = (np.concatenate(P[np.arange(n_folds) != i_fold], axis=0),
            P[i_fold])
    cross_val_folds.append(fold)

# %%
alphas = 10.0 ** (-np.arange(1, 10))
for i, alpha in enumerate(alphas):
    scaler = preprocessing.StandardScaler()
    ridge = linear_model.Ridge(alpha=alpha)

    regressor = pipeline.make_pipeline(scaler, ridge)

    target_prediction = model_selection.cross_val_predict(regressor,
            X=scattering_coef, y=target, cv=cross_val_folds)

    MAE = np.mean(np.abs(target_prediction - target))
    RMSE = np.sqrt(np.mean((target_prediction - target) ** 2))

    print('Ridge regression, alpha: {}, MAE: {}, RMSE: {}'.format(
        alpha, MAE, RMSE))
# Out:
# /home/n7student/miniforge3/envs/env_tensorboard/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:215: LinAlgWarning: Ill-conditioned matrix (rcond=1.33387e-08): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# /home/n7student/miniforge3/envs/env_tensorboard/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:215: LinAlgWarning: Ill-conditioned matrix (rcond=1.07686e-08): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# /home/n7student/miniforge3/envs/env_tensorboard/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:215: LinAlgWarning: Ill-conditioned matrix (rcond=1.12501e-08): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# Ridge regression, alpha: 0.1, MAE: 0.10532165327017542, RMSE: 0.23483194076823094
# Ridge regression, alpha: 0.01, MAE: 0.07055797355808009, RMSE: 0.1080650323234473
# Ridge regression, alpha: 0.001, MAE: 0.05702540359271335, RMSE: 0.3137300333998273
# Ridge regression, alpha: 0.0001, MAE: 0.04637002711104989, RMSE: 0.17110344668240354
# Ridge regression, alpha: 1e-05, MAE: 0.04807538145515325, RMSE: 0.457810791657135
# Ridge regression, alpha: 1e-06, MAE: 0.048342174082255475, RMSE: 0.546280979741625
# Ridge regression, alpha: 1e-07, MAE: 0.044919399887841556, RMSE: 0.409420658805931
# Ridge regression, alpha: 1e-08, MAE: 0.04470880217327474, RMSE: 0.4593835420934678
# Ridge regression, alpha: 1e-09, MAE: 0.04532268813741563, RMSE: 0.5054814510070048

# %%
# Charger et préparer les données de test
test_positions = []
test_charges = []

# Lister tous les fichiers .xyz dans le dossier test
test_files = sorted(os.listdir('../data/atoms/test'))
test_ids = [int(f.split('_')[1].split('.')[0]) for f in test_files]  # Extraire les IDs

# Lire tous les fichiers .xyz de test
for xyz_file in test_files:
    xyz_path = os.path.join('../data/atoms/test', xyz_file)
    atoms = read(xyz_path)
    
    # Obtenir les positions et numéros atomiques
    coords = atoms.get_positions()
    atomic_numbers = atoms.get_atomic_numbers()
    
    # Padding pour avoir une taille fixe
    padded_coords = np.zeros((max_atoms, 3))
    padded_charges = np.zeros(max_atoms)
    
    n_atoms = len(coords)
    padded_coords[:n_atoms] = coords
    padded_charges[:n_atoms] = atomic_numbers
    
    test_positions.append(padded_coords)
    test_charges.append(padded_charges)

# Convertir en arrays numpy
test_pos = np.array(test_positions)
test_full_charges = np.array(test_charges)
n_test_molecules = len(test_pos)

# Appliquer la même normalisation que pour les données d'entraînement
test_pos = test_pos * delta / min_dist

# Calculer les coefficients de scattering pour les données de test
test_order_0 = []
test_orders_1_2 = []

for i in range(0, n_test_molecules, batch_size):
    end = min(i + batch_size, n_test_molecules)
    pos_batch = test_pos[i:end]
    charges_batch = test_full_charges[i:end]
    
    # Calculer les valence charges
    mask = charges_batch <= 2
    val_batch = charges_batch * mask
    mask = np.logical_and(charges_batch > 2, charges_batch <= 10)
    val_batch += (charges_batch - 2) * mask
    mask = np.logical_and(charges_batch > 10, charges_batch <= 18)
    val_batch += (charges_batch - 10) * mask
    
    # Calculer les descripteurs comme pour l'entraînement
    full_density = generate_weighted_sum_of_gaussians(grid, pos_batch, charges_batch, sigma)
    full_density = torch.from_numpy(full_density).to(device).float()
    
    val_density = generate_weighted_sum_of_gaussians(grid, pos_batch, val_batch, sigma)
    val_density = torch.from_numpy(val_density).to(device).float()
    
    core_density = full_density - val_density
    
    # Calculer les coefficients
    full_0 = TorchBackend3D.compute_integrals(full_density, integral_powers)
    full_s = scattering(full_density)
    
    val_0 = TorchBackend3D.compute_integrals(val_density, integral_powers)
    val_s = scattering(val_density)
    
    core_0 = TorchBackend3D.compute_integrals(core_density, integral_powers)
    core_s = scattering(core_density)
    
    # Empiler les coefficients
    batch_0 = torch.stack((full_0, val_0, core_0), dim=-1)
    batch_s = torch.stack((full_s, val_s, core_s), dim=-1)
    
    test_order_0.append(batch_0.cpu())
    test_orders_1_2.append(batch_s.cpu())

# Concatener tous les batches
test_order_0 = torch.cat(test_order_0, dim=0).numpy()
test_orders_1_2 = torch.cat(test_orders_1_2, dim=0).numpy()

# Reshape comme pour l'entraînement
test_order_0 = test_order_0.reshape((n_test_molecules, -1))
test_orders_1_2 = test_orders_1_2.reshape((n_test_molecules, -1))

# Concaténer les descripteurs
test_scattering_coef = np.concatenate([test_order_0, test_orders_1_2], axis=1)
# Out:
# Prédictions sauvegardées dans test_pred.csv
# /home/n7student/miniforge3/envs/env_tensorboard/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:215: LinAlgWarning: Ill-conditioned matrix (rcond=5.85554e-09): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T

# %%
"""basename = 'qm7_L_{}_J_{}_sigma_{}_MNO_{}_powers_{}.npy'.format(
        L, J, sigma, (M, N, O), integral_powers)"""
basename = 'testdataset_L_{}_J_{}_sigma_{}_MNO_{}_powers_{}.npy'.format(
        L, J, sigma, (M, N, O), integral_powers)

# cache_dir = get_cache_dir("qm7/experiments")
save_dir = "save"

filename = os.path.join(save_dir, 'order_0_' + basename)
np.save(filename, test_order_0)

filename = os.path.join(save_dir, 'orders_1_and_2' + basename)
np.save(filename, test_orders_1_2)

# %%
# Entraîner le modèle final sur toutes les données d'entraînement
final_scaler = preprocessing.StandardScaler()
final_ridge = linear_model.Ridge(alpha=0.01)  # Utiliser le meilleur alpha trouvé
final_model = pipeline.make_pipeline(final_scaler, final_ridge)
final_model.fit(scattering_coef, target)

# Faire les prédictions sur les données de test
test_predictions = final_model.predict(test_scattering_coef)

# Créer et sauvegarder le fichier de prédictions
predictions_df = pd.DataFrame({
    'id': test_ids,
    'energy': test_predictions
})
predictions_df.to_csv('../data/energies/test_pred_scattering_fin_alpha_0.01.csv', index=False)
print("Prédictions sauvegardées dans test_pred.csv")
# Out:
# Prédictions sauvegardées dans test_pred.csv
