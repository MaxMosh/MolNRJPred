# %%
import numpy as np
import torch
import time
import os

from sklearn import (linear_model, model_selection, preprocessing,
                     pipeline)
from scipy.spatial.distance import pdist

from kymatio.torch import HarmonicScattering3D

from kymatio.scattering3d.backend.torch_backend \
    import TorchBackend3D

from kymatio.scattering3d.utils \
    import generate_weighted_sum_of_gaussians

from kymatio.datasets import fetch_qm7
from kymatio.caching import get_cache_dir

import random

import pandas as pd
from ase.io import read

# %%
# Charger les données
train_energies = pd.read_csv('../data/energies/train.csv')
molecule_ids = train_energies['id'].values
energies = train_energies['energy'].values

# Initialiser les listes pour stocker toutes les positions et charges
all_positions = []
all_charges = []

# Lire tous les fichiers .xyz avec ASE
for mol_id in molecule_ids:
    xyz_path = f'../data/atoms/train/id_{mol_id}.xyz'
    atoms = read(xyz_path)
    
    # Obtenir les positions et numéros atomiques
    coords = atoms.get_positions()
    atomic_numbers = atoms.get_atomic_numbers()
    
    # Padding pour avoir une taille fixe
    max_atoms = 23  # Ajuster selon le nombre maximum d'atomes
    padded_coords = np.zeros((max_atoms, 3))
    padded_charges = np.zeros(max_atoms)
    
    n_atoms = len(coords)
    padded_coords[:n_atoms] = coords
    padded_charges[:n_atoms] = atomic_numbers
    
    all_positions.append(padded_coords)
    all_charges.append(padded_charges)

# Convertir en arrays numpy
pos = np.array(all_positions)
full_charges = np.array(all_charges)
target = energies

# Le reste du code reste identique à partir de la définition de n_molecules
n_molecules = len(pos)

# ...existing code...

# %%
"""qm7 = fetch_qm7(align=True)
pos = qm7['positions']
full_charges = qm7['charges']

n_molecules = pos.shape[0]"""

# %%
"""n_molecules_tot = len(pos)
n_molecules = 5
indices = random.sample(range(n_molecules_tot), n_molecules)

pos = pos[indices]
full_charges = full_charges[indices]"""

# %%
mask = full_charges <= 2
valence_charges = full_charges * mask

mask = np.logical_and(full_charges > 2, full_charges <= 10)
valence_charges += (full_charges - 2) * mask

mask = np.logical_and(full_charges > 10, full_charges <= 18)
valence_charges += (full_charges - 10) * mask

# %%
overlapping_precision = 1e-1
sigma = 2.0
min_dist = np.inf

for i in range(n_molecules):
    n_atoms = np.sum(full_charges[i] != 0)
    pos_i = pos[i, :n_atoms, :]
    min_dist = min(min_dist, pdist(pos_i).min())

delta = sigma * np.sqrt(-8 * np.log(overlapping_precision))
pos = pos * delta / min_dist

# %%
#M, N, O = 192, 128, 96
M, N, O = 32, 32, 32

grid = np.mgrid[-M//2:-M//2+M, -N//2:-N//2+N, -O//2:-O//2+O]
grid = np.fft.ifftshift(grid)

# %%
# J = 2
# L = 3
J = 1
L = 2
integral_powers = [0.5, 1.0, 2.0, 3.0]

scattering = HarmonicScattering3D(J=J, shape=(M, N, O),
                                  L=L, sigma_0=sigma,
                                  integral_powers=integral_powers)

# %%
use_cuda = torch.cuda.is_available()
device = torch.device("cuda" if use_cuda else "cpu")
scattering.to(device)
# Out:
# HarmonicScattering3D()

# %%
batch_size = 8
#batch_size = 16
n_batches = int(np.ceil(n_molecules / batch_size))

# %%
order_0, orders_1_and_2 = [], []
print('Computing solid harmonic scattering coefficients of '
      '{} molecules from the QM7 database on {}'.format(
        n_molecules,   "GPU" if use_cuda else "CPU"))
print('sigma: {}, L: {}, J: {}, integral powers: {}'.format(
        sigma, L, J, integral_powers))

this_time = None
last_time = None
for i in range(n_batches):
    this_time = time.time()
    if last_time is not None:
        dt = this_time - last_time
        print("Iteration {} ETA: [{:02}:{:02}:{:02}]".format(
                    i + 1, int(((n_batches - i - 1) * dt) // 3600),
                    int((((n_batches - i - 1) * dt) // 60) % 60),
                    int(((n_batches - i - 1) * dt) % 60)))
    else:
        print("Iteration {} ETA: {}".format(i + 1, '-'))
    last_time = this_time
    time.sleep(1)

    # Extract the current batch.
    start = i * batch_size
    end = min(start + batch_size, n_molecules)

    pos_batch = pos[start:end]
    full_batch = full_charges[start:end]
    val_batch = valence_charges[start:end]

    # Calculate the density map for the nuclear charges and transfer
    # to PyTorch.
    full_density_batch = generate_weighted_sum_of_gaussians(grid,
            pos_batch, full_batch, sigma)
    full_density_batch = torch.from_numpy(full_density_batch)
    full_density_batch = full_density_batch.to(device).float()

    # Compute zeroth-order, first-order, and second-order scattering
    # coefficients of the nuclear charges.
    full_order_0 = TorchBackend3D.compute_integrals(full_density_batch,
                                     integral_powers)
    full_scattering = scattering(full_density_batch)

    # Compute the map for valence charges.
    val_density_batch = generate_weighted_sum_of_gaussians(grid,
            pos_batch, val_batch, sigma)
    val_density_batch = torch.from_numpy(val_density_batch)
    val_density_batch = val_density_batch.to(device).float()

    # Compute scattering coefficients for the valence charges.
    val_order_0 = TorchBackend3D.compute_integrals(val_density_batch,
                                    integral_powers)
    val_scattering = scattering(val_density_batch)

    # Take the difference between nuclear and valence charges, then
    # compute the corresponding scattering coefficients.
    core_density_batch = full_density_batch - val_density_batch

    core_order_0 = TorchBackend3D.compute_integrals(core_density_batch,
                                     integral_powers)
    core_scattering = scattering(core_density_batch)

    # Stack the nuclear, valence, and core coefficients into arrays
    # and append them to the output.
    batch_order_0 = torch.stack(
        (full_order_0, val_order_0, core_order_0), dim=-1)
    batch_orders_1_and_2 = torch.stack(
        (full_scattering, val_scattering, core_scattering), dim=-1)

    order_0.append(batch_order_0)
    orders_1_and_2.append(batch_orders_1_and_2)
# Out:
# Computing solid harmonic scattering coefficients of 6591 molecules from the QM7 database on GPU
# sigma: 2.0, L: 2, J: 1, integral powers: [0.5, 1.0, 2.0, 3.0]
# Iteration 1 ETA: -
# Iteration 2 ETA: [00:18:54]
# Iteration 3 ETA: [00:17:31]
# Iteration 4 ETA: [00:17:32]
# Iteration 5 ETA: [00:17:28]
# Iteration 6 ETA: [00:17:28]
# Iteration 7 ETA: [00:17:24]
# Iteration 8 ETA: [00:17:25]
# Iteration 9 ETA: [00:17:24]
# Iteration 10 ETA: [00:17:22]
# Iteration 11 ETA: [00:17:24]
# Iteration 12 ETA: [00:17:24]
# Iteration 13 ETA: [00:17:19]
# Iteration 14 ETA: [00:17:17]
# Iteration 15 ETA: [00:17:19]
# Iteration 16 ETA: [00:17:15]
# Iteration 17 ETA: [00:17:12]
# Iteration 18 ETA: [00:17:14]
# Iteration 19 ETA: [00:17:11]
# Iteration 20 ETA: [00:17:07]
# Iteration 21 ETA: [00:17:10]
# Iteration 22 ETA: [00:17:04]
# Iteration 23 ETA: [00:17:05]
# Iteration 24 ETA: [00:17:06]
# Iteration 25 ETA: [00:17:05]
# Iteration 26 ETA: [00:17:05]
# Iteration 27 ETA: [00:17:03]
# Iteration 28 ETA: [00:17:00]
# Iteration 29 ETA: [00:16:58]
# Iteration 30 ETA: [00:16:58]
# Iteration 31 ETA: [00:17:00]
# Iteration 32 ETA: [00:16:57]
# Iteration 33 ETA: [00:16:58]
# Iteration 34 ETA: [00:16:54]
# Iteration 35 ETA: [00:16:57]
# Iteration 36 ETA: [00:16:51]
# Iteration 37 ETA: [00:16:46]
# Iteration 38 ETA: [00:16:48]
# Iteration 39 ETA: [00:16:48]
# Iteration 40 ETA: [00:16:46]
# Iteration 41 ETA: [00:16:45]
# Iteration 42 ETA: [00:16:42]
# Iteration 43 ETA: [00:16:43]
# Iteration 44 ETA: [00:16:40]
# Iteration 45 ETA: [00:16:43]
# Iteration 46 ETA: [00:16:41]
# Iteration 47 ETA: [00:16:40]
# Iteration 48 ETA: [00:16:43]
# Iteration 49 ETA: [00:16:42]
# Iteration 50 ETA: [00:16:31]
# Iteration 51 ETA: [00:16:32]
# Iteration 52 ETA: [00:16:33]
# Iteration 53 ETA: [00:16:31]
# Iteration 54 ETA: [00:16:35]
# Iteration 55 ETA: [00:16:23]
# Iteration 56 ETA: [00:16:32]
# Iteration 57 ETA: [00:16:28]
# Iteration 58 ETA: [00:16:28]
# Iteration 59 ETA: [00:16:20]
# Iteration 60 ETA: [00:16:21]
# Iteration 61 ETA: [00:16:19]
# Iteration 62 ETA: [00:16:17]
# Iteration 63 ETA: [00:16:16]
# Iteration 64 ETA: [00:16:14]
# Iteration 65 ETA: [00:16:15]
# Iteration 66 ETA: [00:16:11]
# Iteration 67 ETA: [00:16:11]
# Iteration 68 ETA: [00:16:10]
# Iteration 69 ETA: [00:16:12]
# Iteration 70 ETA: [00:16:10]
# Iteration 71 ETA: [00:16:21]
# Iteration 72 ETA: [00:16:17]
# Iteration 73 ETA: [00:16:11]
# Iteration 74 ETA: [00:16:08]
# Iteration 75 ETA: [00:16:07]
# Iteration 76 ETA: [00:16:03]
# Iteration 77 ETA: [00:16:01]
# Iteration 78 ETA: [00:16:02]
# Iteration 79 ETA: [00:15:57]
# Iteration 80 ETA: [00:16:00]
# Iteration 81 ETA: [00:15:54]
# Iteration 82 ETA: [00:15:57]
# Iteration 83 ETA: [00:15:57]
# Iteration 84 ETA: [00:15:51]
# Iteration 85 ETA: [00:16:00]
# Iteration 86 ETA: [00:15:45]
# Iteration 87 ETA: [00:15:44]
# Iteration 88 ETA: [00:15:56]
# Iteration 89 ETA: [00:15:42]
# Iteration 90 ETA: [00:15:41]
# Iteration 91 ETA: [00:15:44]
# Iteration 92 ETA: [00:15:39]
# Iteration 93 ETA: [00:15:37]
# Iteration 94 ETA: [00:15:37]
# Iteration 95 ETA: [00:15:32]
# Iteration 96 ETA: [00:15:39]
# Iteration 97 ETA: [00:15:43]
# Iteration 98 ETA: [00:15:39]
# Iteration 99 ETA: [00:15:46]
# Iteration 100 ETA: [00:15:36]
# Iteration 101 ETA: [00:15:34]
# Iteration 102 ETA: [00:15:30]
# Iteration 103 ETA: [00:15:50]
# Iteration 104 ETA: [00:15:33]
# Iteration 105 ETA: [00:15:27]
# Iteration 106 ETA: [00:15:30]
# Iteration 107 ETA: [00:15:22]
# Iteration 108 ETA: [00:15:21]
# Iteration 109 ETA: [00:15:22]
# Iteration 110 ETA: [00:15:21]
# Iteration 111 ETA: [00:15:12]
# Iteration 112 ETA: [00:15:12]
# Iteration 113 ETA: [00:15:11]
# Iteration 114 ETA: [00:15:07]
# Iteration 115 ETA: [00:15:09]
# Iteration 116 ETA: [00:15:07]
# Iteration 117 ETA: [00:15:05]
# Iteration 118 ETA: [00:15:07]
# Iteration 119 ETA: [00:15:05]
# Iteration 120 ETA: [00:15:02]
# Iteration 121 ETA: [00:15:02]
# Iteration 122 ETA: [00:14:59]
# Iteration 123 ETA: [00:15:03]
# Iteration 124 ETA: [00:14:58]
# Iteration 125 ETA: [00:14:57]
# Iteration 126 ETA: [00:14:54]
# Iteration 127 ETA: [00:14:54]
# Iteration 128 ETA: [00:14:49]
# Iteration 129 ETA: [00:14:51]
# Iteration 130 ETA: [00:14:47]
# Iteration 131 ETA: [00:14:49]
# Iteration 132 ETA: [00:14:52]
# Iteration 133 ETA: [00:14:48]
# Iteration 134 ETA: [00:14:47]
# Iteration 135 ETA: [00:14:43]
# Iteration 136 ETA: [00:14:44]
# Iteration 137 ETA: [00:14:41]
# Iteration 138 ETA: [00:14:41]
# Iteration 139 ETA: [00:14:42]
# Iteration 140 ETA: [00:14:40]
# Iteration 141 ETA: [00:14:42]
# Iteration 142 ETA: [00:14:36]
# Iteration 143 ETA: [00:14:43]
# Iteration 144 ETA: [00:14:38]
# Iteration 145 ETA: [00:14:35]
# Iteration 146 ETA: [00:14:30]
# Iteration 147 ETA: [00:14:34]
# Iteration 148 ETA: [00:14:33]
# Iteration 149 ETA: [00:14:31]
# Iteration 150 ETA: [00:14:30]
# Iteration 151 ETA: [00:14:26]
# Iteration 152 ETA: [00:14:31]
# Iteration 153 ETA: [00:14:25]
# Iteration 154 ETA: [00:14:25]
# Iteration 155 ETA: [00:14:22]
# Iteration 156 ETA: [00:14:20]
# Iteration 157 ETA: [00:14:22]
# Iteration 158 ETA: [00:14:21]
# Iteration 159 ETA: [00:14:16]
# Iteration 160 ETA: [00:14:16]
# Iteration 161 ETA: [00:14:13]
# Iteration 162 ETA: [00:14:12]
# Iteration 163 ETA: [00:14:09]
# Iteration 164 ETA: [00:14:06]
# Iteration 165 ETA: [00:14:05]
# Iteration 166 ETA: [00:14:03]
# Iteration 167 ETA: [00:14:01]
# Iteration 168 ETA: [00:14:00]
# Iteration 169 ETA: [00:13:58]
# Iteration 170 ETA: [00:13:58]
# Iteration 171 ETA: [00:13:56]
# Iteration 172 ETA: [00:13:58]
# Iteration 173 ETA: [00:13:56]
# Iteration 174 ETA: [00:13:54]
# Iteration 175 ETA: [00:13:49]
# Iteration 176 ETA: [00:13:52]
# Iteration 177 ETA: [00:13:49]
# Iteration 178 ETA: [00:13:49]
# Iteration 179 ETA: [00:13:51]
# Iteration 180 ETA: [00:13:43]
# Iteration 181 ETA: [00:13:43]
# Iteration 182 ETA: [00:13:43]
# Iteration 183 ETA: [00:13:38]
# Iteration 184 ETA: [00:13:44]
# Iteration 185 ETA: [00:13:37]
# Iteration 186 ETA: [00:13:35]
# Iteration 187 ETA: [00:13:34]
# Iteration 188 ETA: [00:13:35]
# Iteration 189 ETA: [00:13:33]
# Iteration 190 ETA: [00:13:31]
# Iteration 191 ETA: [00:13:31]
# Iteration 192 ETA: [00:13:32]
# Iteration 193 ETA: [00:13:27]
# Iteration 194 ETA: [00:13:26]
# Iteration 195 ETA: [00:13:27]
# Iteration 196 ETA: [00:13:27]
# Iteration 197 ETA: [00:13:24]
# Iteration 198 ETA: [00:13:23]
# Iteration 199 ETA: [00:13:19]
# Iteration 200 ETA: [00:13:20]
# Iteration 201 ETA: [00:13:17]
# Iteration 202 ETA: [00:13:18]
# Iteration 203 ETA: [00:13:15]
# Iteration 204 ETA: [00:13:11]
# Iteration 205 ETA: [00:13:11]
# Iteration 206 ETA: [00:13:12]
# Iteration 207 ETA: [00:13:09]
# Iteration 208 ETA: [00:13:08]
# Iteration 209 ETA: [00:13:06]
# Iteration 210 ETA: [00:13:04]
# Iteration 211 ETA: [00:13:06]
# Iteration 212 ETA: [00:13:02]
# Iteration 213 ETA: [00:13:02]
# Iteration 214 ETA: [00:13:02]
# Iteration 215 ETA: [00:13:01]
# Iteration 216 ETA: [00:12:58]
# Iteration 217 ETA: [00:12:58]
# Iteration 218 ETA: [00:12:56]
# Iteration 219 ETA: [00:12:55]
# Iteration 220 ETA: [00:12:51]
# Iteration 221 ETA: [00:12:51]
# Iteration 222 ETA: [00:12:49]
# Iteration 223 ETA: [00:12:48]
# Iteration 224 ETA: [00:12:48]
# Iteration 225 ETA: [00:12:46]
# Iteration 226 ETA: [00:12:45]
# Iteration 227 ETA: [00:12:43]
# Iteration 228 ETA: [00:12:43]
# Iteration 229 ETA: [00:12:40]
# Iteration 230 ETA: [00:12:42]
# Iteration 231 ETA: [00:12:40]
# Iteration 232 ETA: [00:12:38]
# Iteration 233 ETA: [00:12:38]
# Iteration 234 ETA: [00:12:34]
# Iteration 235 ETA: [00:12:33]
# Iteration 236 ETA: [00:12:32]
# Iteration 237 ETA: [00:12:31]
# Iteration 238 ETA: [00:12:31]
# Iteration 239 ETA: [00:12:28]
# Iteration 240 ETA: [00:12:29]
# Iteration 241 ETA: [00:12:27]
# Iteration 242 ETA: [00:12:23]
# Iteration 243 ETA: [00:12:24]
# Iteration 244 ETA: [00:12:21]
# Iteration 245 ETA: [00:12:20]
# Iteration 246 ETA: [00:12:20]
# Iteration 247 ETA: [00:12:17]
# Iteration 248 ETA: [00:12:22]
# Iteration 249 ETA: [00:12:14]
# Iteration 250 ETA: [00:12:14]
# Iteration 251 ETA: [00:12:13]
# Iteration 252 ETA: [00:12:14]
# Iteration 253 ETA: [00:12:09]
# Iteration 254 ETA: [00:12:10]
# Iteration 255 ETA: [00:12:08]
# Iteration 256 ETA: [00:12:06]
# Iteration 257 ETA: [00:12:05]
# Iteration 258 ETA: [00:12:03]
# Iteration 259 ETA: [00:12:04]
# Iteration 260 ETA: [00:12:00]
# Iteration 261 ETA: [00:12:01]
# Iteration 262 ETA: [00:11:59]
# Iteration 263 ETA: [00:11:56]
# Iteration 264 ETA: [00:11:55]
# Iteration 265 ETA: [00:11:55]
# Iteration 266 ETA: [00:12:02]
# Iteration 267 ETA: [00:11:53]
# Iteration 268 ETA: [00:11:51]
# Iteration 269 ETA: [00:11:49]
# Iteration 270 ETA: [00:11:49]
# Iteration 271 ETA: [00:11:47]
# Iteration 272 ETA: [00:11:46]
# Iteration 273 ETA: [00:11:45]
# Iteration 274 ETA: [00:11:44]
# Iteration 275 ETA: [00:11:44]
# Iteration 276 ETA: [00:11:42]
# Iteration 277 ETA: [00:11:43]
# Iteration 278 ETA: [00:11:38]
# Iteration 279 ETA: [00:11:39]
# Iteration 280 ETA: [00:11:40]
# Iteration 281 ETA: [00:11:35]
# Iteration 282 ETA: [00:11:33]
# Iteration 283 ETA: [00:11:32]
# Iteration 284 ETA: [00:11:33]
# Iteration 285 ETA: [00:11:30]
# Iteration 286 ETA: [00:11:28]
# Iteration 287 ETA: [00:11:28]
# Iteration 288 ETA: [00:11:26]
# Iteration 289 ETA: [00:11:24]
# Iteration 290 ETA: [00:11:22]
# Iteration 291 ETA: [00:11:21]
# Iteration 292 ETA: [00:11:20]
# Iteration 293 ETA: [00:11:21]
# Iteration 294 ETA: [00:11:18]
# Iteration 295 ETA: [00:11:20]
# Iteration 296 ETA: [00:11:17]
# Iteration 297 ETA: [00:11:14]
# Iteration 298 ETA: [00:11:11]
# Iteration 299 ETA: [00:11:13]
# Iteration 300 ETA: [00:11:12]
# Iteration 301 ETA: [00:11:10]
# Iteration 302 ETA: [00:11:08]
# Iteration 303 ETA: [00:11:05]
# Iteration 304 ETA: [00:11:07]
# Iteration 305 ETA: [00:11:06]
# Iteration 306 ETA: [00:11:04]
# Iteration 307 ETA: [00:11:03]
# Iteration 308 ETA: [00:11:00]
# Iteration 309 ETA: [00:11:00]
# Iteration 310 ETA: [00:10:57]
# Iteration 311 ETA: [00:10:58]
# Iteration 312 ETA: [00:10:54]
# Iteration 313 ETA: [00:10:57]
# Iteration 314 ETA: [00:10:53]
# Iteration 315 ETA: [00:10:52]
# Iteration 316 ETA: [00:10:51]
# Iteration 317 ETA: [00:10:50]
# Iteration 318 ETA: [00:10:48]
# Iteration 319 ETA: [00:10:47]
# Iteration 320 ETA: [00:10:44]
# Iteration 321 ETA: [00:10:42]
# Iteration 322 ETA: [00:10:43]
# Iteration 323 ETA: [00:10:43]
# Iteration 324 ETA: [00:10:41]
# Iteration 325 ETA: [00:10:40]
# Iteration 326 ETA: [00:10:35]
# Iteration 327 ETA: [00:10:36]
# Iteration 328 ETA: [00:10:34]
# Iteration 329 ETA: [00:10:34]
# Iteration 330 ETA: [00:10:32]
# Iteration 331 ETA: [00:10:29]
# Iteration 332 ETA: [00:10:29]
# Iteration 333 ETA: [00:10:29]
# Iteration 334 ETA: [00:10:29]
# Iteration 335 ETA: [00:10:25]
# Iteration 336 ETA: [00:10:24]
# Iteration 337 ETA: [00:10:21]
# Iteration 338 ETA: [00:10:23]
# Iteration 339 ETA: [00:10:20]
# Iteration 340 ETA: [00:10:21]
# Iteration 341 ETA: [00:10:18]
# Iteration 342 ETA: [00:10:16]
# Iteration 343 ETA: [00:10:16]
# Iteration 344 ETA: [00:10:13]
# Iteration 345 ETA: [00:10:12]
# Iteration 346 ETA: [00:10:12]
# Iteration 347 ETA: [00:10:08]
# Iteration 348 ETA: [00:10:09]
# Iteration 349 ETA: [00:10:07]
# Iteration 350 ETA: [00:10:06]
# Iteration 351 ETA: [00:10:06]
# Iteration 352 ETA: [00:10:04]
# Iteration 353 ETA: [00:10:04]
# Iteration 354 ETA: [00:10:00]
# Iteration 355 ETA: [00:10:00]
# Iteration 356 ETA: [00:09:58]
# Iteration 357 ETA: [00:09:58]
# Iteration 358 ETA: [00:09:59]
# Iteration 359 ETA: [00:09:55]
# Iteration 360 ETA: [00:09:52]
# Iteration 361 ETA: [00:09:53]
# Iteration 362 ETA: [00:09:51]
# Iteration 363 ETA: [00:09:51]
# Iteration 364 ETA: [00:09:48]
# Iteration 365 ETA: [00:09:47]
# Iteration 366 ETA: [00:09:46]
# Iteration 367 ETA: [00:09:45]
# Iteration 368 ETA: [00:09:44]
# Iteration 369 ETA: [00:09:41]
# Iteration 370 ETA: [00:09:42]
# Iteration 371 ETA: [00:09:41]
# Iteration 372 ETA: [00:09:40]
# Iteration 373 ETA: [00:09:38]
# Iteration 374 ETA: [00:09:35]
# Iteration 375 ETA: [00:09:36]
# Iteration 376 ETA: [00:09:34]
# Iteration 377 ETA: [00:09:34]
# Iteration 378 ETA: [00:09:30]
# Iteration 379 ETA: [00:09:31]
# Iteration 380 ETA: [00:09:28]
# Iteration 381 ETA: [00:09:27]
# Iteration 382 ETA: [00:09:26]
# Iteration 383 ETA: [00:09:24]
# Iteration 384 ETA: [00:09:23]
# Iteration 385 ETA: [00:09:22]
# Iteration 386 ETA: [00:09:22]
# Iteration 387 ETA: [00:09:19]
# Iteration 388 ETA: [00:09:16]
# Iteration 389 ETA: [00:09:16]
# Iteration 390 ETA: [00:09:15]
# Iteration 391 ETA: [00:09:12]
# Iteration 392 ETA: [00:09:12]
# Iteration 393 ETA: [00:09:11]
# Iteration 394 ETA: [00:09:09]
# Iteration 395 ETA: [00:09:08]
# Iteration 396 ETA: [00:09:07]
# Iteration 397 ETA: [00:09:09]
# Iteration 398 ETA: [00:09:04]
# Iteration 399 ETA: [00:09:05]
# Iteration 400 ETA: [00:09:03]
# Iteration 401 ETA: [00:09:03]
# Iteration 402 ETA: [00:08:58]
# Iteration 403 ETA: [00:09:00]
# Iteration 404 ETA: [00:08:57]
# Iteration 405 ETA: [00:08:57]
# Iteration 406 ETA: [00:08:55]
# Iteration 407 ETA: [00:08:56]
# Iteration 408 ETA: [00:08:53]
# Iteration 409 ETA: [00:08:52]
# Iteration 410 ETA: [00:08:49]
# Iteration 411 ETA: [00:08:51]
# Iteration 412 ETA: [00:08:46]
# Iteration 413 ETA: [00:08:47]
# Iteration 414 ETA: [00:08:46]
# Iteration 415 ETA: [00:08:44]
# Iteration 416 ETA: [00:08:40]
# Iteration 417 ETA: [00:08:41]
# Iteration 418 ETA: [00:08:39]
# Iteration 419 ETA: [00:08:38]
# Iteration 420 ETA: [00:08:38]
# Iteration 421 ETA: [00:08:38]
# Iteration 422 ETA: [00:08:36]
# Iteration 423 ETA: [00:08:34]
# Iteration 424 ETA: [00:08:32]
# Iteration 425 ETA: [00:08:32]
# Iteration 426 ETA: [00:08:30]
# Iteration 427 ETA: [00:08:25]
# Iteration 428 ETA: [00:08:27]
# Iteration 429 ETA: [00:08:25]
# Iteration 430 ETA: [00:08:23]
# Iteration 431 ETA: [00:08:23]
# Iteration 432 ETA: [00:08:22]
# Iteration 433 ETA: [00:08:23]
# Iteration 434 ETA: [00:08:19]
# Iteration 435 ETA: [00:08:18]
# Iteration 436 ETA: [00:08:16]
# Iteration 437 ETA: [00:08:24]
# Iteration 438 ETA: [00:08:14]
# Iteration 439 ETA: [00:08:13]
# Iteration 440 ETA: [00:08:10]
# Iteration 441 ETA: [00:08:11]
# Iteration 442 ETA: [00:08:10]
# Iteration 443 ETA: [00:08:07]
# Iteration 444 ETA: [00:08:06]
# Iteration 445 ETA: [00:08:06]
# Iteration 446 ETA: [00:08:05]
# Iteration 447 ETA: [00:08:03]
# Iteration 448 ETA: [00:08:00]
# Iteration 449 ETA: [00:08:00]
# Iteration 450 ETA: [00:08:00]
# Iteration 451 ETA: [00:08:03]
# Iteration 452 ETA: [00:07:56]
# Iteration 453 ETA: [00:07:55]
# Iteration 454 ETA: [00:07:56]
# Iteration 455 ETA: [00:07:53]
# Iteration 456 ETA: [00:07:52]
# Iteration 457 ETA: [00:07:49]
# Iteration 458 ETA: [00:07:49]
# Iteration 459 ETA: [00:07:47]
# Iteration 460 ETA: [00:07:46]
# Iteration 461 ETA: [00:07:46]
# Iteration 462 ETA: [00:07:43]
# Iteration 463 ETA: [00:07:41]
# Iteration 464 ETA: [00:07:41]
# Iteration 465 ETA: [00:07:39]
# Iteration 466 ETA: [00:07:39]
# Iteration 467 ETA: [00:07:36]
# Iteration 468 ETA: [00:07:36]
# Iteration 469 ETA: [00:07:35]
# Iteration 470 ETA: [00:07:34]
# Iteration 471 ETA: [00:07:31]
# Iteration 472 ETA: [00:07:30]
# Iteration 473 ETA: [00:07:28]
# Iteration 474 ETA: [00:07:28]
# Iteration 475 ETA: [00:07:26]
# Iteration 476 ETA: [00:07:25]
# Iteration 477 ETA: [00:07:25]
# Iteration 478 ETA: [00:07:22]
# Iteration 479 ETA: [00:07:21]
# Iteration 480 ETA: [00:07:21]
# Iteration 481 ETA: [00:07:17]
# Iteration 482 ETA: [00:07:18]
# Iteration 483 ETA: [00:07:17]
# Iteration 484 ETA: [00:07:14]
# Iteration 485 ETA: [00:07:14]
# Iteration 486 ETA: [00:07:12]
# Iteration 487 ETA: [00:07:11]
# Iteration 488 ETA: [00:07:10]
# Iteration 489 ETA: [00:07:08]
# Iteration 490 ETA: [00:07:08]
# Iteration 491 ETA: [00:07:06]
# Iteration 492 ETA: [00:07:03]
# Iteration 493 ETA: [00:07:03]
# Iteration 494 ETA: [00:07:00]
# Iteration 495 ETA: [00:07:00]
# Iteration 496 ETA: [00:07:00]
# Iteration 497 ETA: [00:06:58]
# Iteration 498 ETA: [00:06:56]
# Iteration 499 ETA: [00:06:55]
# Iteration 500 ETA: [00:06:54]
# Iteration 501 ETA: [00:06:54]
# Iteration 502 ETA: [00:06:51]
# Iteration 503 ETA: [00:06:50]
# Iteration 504 ETA: [00:06:49]
# Iteration 505 ETA: [00:06:46]
# Iteration 506 ETA: [00:06:46]
# Iteration 507 ETA: [00:06:44]
# Iteration 508 ETA: [00:06:46]
# Iteration 509 ETA: [00:06:42]
# Iteration 510 ETA: [00:06:41]
# Iteration 511 ETA: [00:06:40]
# Iteration 512 ETA: [00:06:39]
# Iteration 513 ETA: [00:06:39]
# Iteration 514 ETA: [00:06:36]
# Iteration 515 ETA: [00:06:35]
# Iteration 516 ETA: [00:06:33]
# Iteration 517 ETA: [00:06:32]
# Iteration 518 ETA: [00:06:32]
# Iteration 519 ETA: [00:06:28]
# Iteration 520 ETA: [00:06:27]
# Iteration 521 ETA: [00:06:27]
# Iteration 522 ETA: [00:06:25]
# Iteration 523 ETA: [00:06:26]
# Iteration 524 ETA: [00:06:23]
# Iteration 525 ETA: [00:06:21]
# Iteration 526 ETA: [00:06:22]
# Iteration 527 ETA: [00:06:19]
# Iteration 528 ETA: [00:06:18]
# Iteration 529 ETA: [00:06:21]
# Iteration 530 ETA: [00:06:16]
# Iteration 531 ETA: [00:06:15]
# Iteration 532 ETA: [00:06:13]
# Iteration 533 ETA: [00:06:11]
# Iteration 534 ETA: [00:06:11]
# Iteration 535 ETA: [00:06:09]
# Iteration 536 ETA: [00:06:08]
# Iteration 537 ETA: [00:06:07]
# Iteration 538 ETA: [00:06:05]
# Iteration 539 ETA: [00:06:04]
# Iteration 540 ETA: [00:06:04]
# Iteration 541 ETA: [00:06:03]
# Iteration 542 ETA: [00:06:01]
# Iteration 543 ETA: [00:05:59]
# Iteration 544 ETA: [00:05:57]
# Iteration 545 ETA: [00:05:57]
# Iteration 546 ETA: [00:05:56]
# Iteration 547 ETA: [00:05:54]
# Iteration 548 ETA: [00:05:54]
# Iteration 549 ETA: [00:05:53]
# Iteration 550 ETA: [00:05:51]
# Iteration 551 ETA: [00:05:49]
# Iteration 552 ETA: [00:05:47]
# Iteration 553 ETA: [00:05:46]
# Iteration 554 ETA: [00:05:45]
# Iteration 555 ETA: [00:05:44]
# Iteration 556 ETA: [00:05:42]
# Iteration 557 ETA: [00:05:41]
# Iteration 558 ETA: [00:05:39]
# Iteration 559 ETA: [00:05:38]
# Iteration 560 ETA: [00:05:37]
# Iteration 561 ETA: [00:05:36]
# Iteration 562 ETA: [00:05:35]
# Iteration 563 ETA: [00:05:35]
# Iteration 564 ETA: [00:05:33]
# Iteration 565 ETA: [00:05:32]
# Iteration 566 ETA: [00:05:30]
# Iteration 567 ETA: [00:05:29]
# Iteration 568 ETA: [00:05:27]
# Iteration 569 ETA: [00:05:26]
# Iteration 570 ETA: [00:05:25]
# Iteration 571 ETA: [00:05:22]
# Iteration 572 ETA: [00:05:22]
# Iteration 573 ETA: [00:05:20]
# Iteration 574 ETA: [00:05:20]
# Iteration 575 ETA: [00:05:19]
# Iteration 576 ETA: [00:05:16]
# Iteration 577 ETA: [00:05:15]
# Iteration 578 ETA: [00:05:15]
# Iteration 579 ETA: [00:05:12]
# Iteration 580 ETA: [00:05:13]
# Iteration 581 ETA: [00:05:12]
# Iteration 582 ETA: [00:05:09]
# Iteration 583 ETA: [00:05:08]
# Iteration 584 ETA: [00:05:06]
# Iteration 585 ETA: [00:05:05]
# Iteration 586 ETA: [00:05:04]
# Iteration 587 ETA: [00:05:02]
# Iteration 588 ETA: [00:05:02]
# Iteration 589 ETA: [00:05:00]
# Iteration 590 ETA: [00:04:59]
# Iteration 591 ETA: [00:04:57]
# Iteration 592 ETA: [00:04:57]
# Iteration 593 ETA: [00:04:55]
# Iteration 594 ETA: [00:04:55]
# Iteration 595 ETA: [00:04:55]
# Iteration 596 ETA: [00:04:51]
# Iteration 597 ETA: [00:04:51]
# Iteration 598 ETA: [00:04:50]
# Iteration 599 ETA: [00:04:47]
# Iteration 600 ETA: [00:04:47]
# Iteration 601 ETA: [00:04:46]
# Iteration 602 ETA: [00:04:45]
# Iteration 603 ETA: [00:04:43]
# Iteration 604 ETA: [00:04:42]
# Iteration 605 ETA: [00:04:40]
# Iteration 606 ETA: [00:04:39]
# Iteration 607 ETA: [00:04:38]
# Iteration 608 ETA: [00:04:36]
# Iteration 609 ETA: [00:04:35]
# Iteration 610 ETA: [00:04:34]
# Iteration 611 ETA: [00:04:32]
# Iteration 612 ETA: [00:04:32]
# Iteration 613 ETA: [00:04:30]
# Iteration 614 ETA: [00:04:28]
# Iteration 615 ETA: [00:04:29]
# Iteration 616 ETA: [00:04:26]
# Iteration 617 ETA: [00:04:26]
# Iteration 618 ETA: [00:04:23]
# Iteration 619 ETA: [00:04:23]
# Iteration 620 ETA: [00:04:20]
# Iteration 621 ETA: [00:04:21]
# Iteration 622 ETA: [00:04:18]
# Iteration 623 ETA: [00:04:19]
# Iteration 624 ETA: [00:04:16]
# Iteration 625 ETA: [00:04:15]
# Iteration 626 ETA: [00:04:14]
# Iteration 627 ETA: [00:04:13]
# Iteration 628 ETA: [00:04:10]
# Iteration 629 ETA: [00:04:10]
# Iteration 630 ETA: [00:04:08]
# Iteration 631 ETA: [00:04:07]
# Iteration 632 ETA: [00:04:05]
# Iteration 633 ETA: [00:04:04]
# Iteration 634 ETA: [00:04:03]
# Iteration 635 ETA: [00:04:02]
# Iteration 636 ETA: [00:03:59]
# Iteration 637 ETA: [00:03:59]
# Iteration 638 ETA: [00:03:58]
# Iteration 639 ETA: [00:03:56]
# Iteration 640 ETA: [00:03:55]
# Iteration 641 ETA: [00:03:54]
# Iteration 642 ETA: [00:03:53]
# Iteration 643 ETA: [00:03:52]
# Iteration 644 ETA: [00:03:50]
# Iteration 645 ETA: [00:03:49]
# Iteration 646 ETA: [00:03:48]
# Iteration 647 ETA: [00:03:47]
# Iteration 648 ETA: [00:03:45]
# Iteration 649 ETA: [00:03:44]
# Iteration 650 ETA: [00:03:42]
# Iteration 651 ETA: [00:03:40]
# Iteration 652 ETA: [00:03:40]
# Iteration 653 ETA: [00:03:39]
# Iteration 654 ETA: [00:03:37]
# Iteration 655 ETA: [00:03:36]
# Iteration 656 ETA: [00:03:35]
# Iteration 657 ETA: [00:03:35]
# Iteration 658 ETA: [00:03:32]
# Iteration 659 ETA: [00:03:31]
# Iteration 660 ETA: [00:03:30]
# Iteration 661 ETA: [00:03:28]
# Iteration 662 ETA: [00:03:27]
# Iteration 663 ETA: [00:03:26]
# Iteration 664 ETA: [00:03:25]
# Iteration 665 ETA: [00:03:23]
# Iteration 666 ETA: [00:03:21]
# Iteration 667 ETA: [00:03:20]
# Iteration 668 ETA: [00:03:19]
# Iteration 669 ETA: [00:03:18]
# Iteration 670 ETA: [00:03:17]
# Iteration 671 ETA: [00:03:17]
# Iteration 672 ETA: [00:03:14]
# Iteration 673 ETA: [00:03:13]
# Iteration 674 ETA: [00:03:12]
# Iteration 675 ETA: [00:03:11]
# Iteration 676 ETA: [00:03:09]
# Iteration 677 ETA: [00:03:08]
# Iteration 678 ETA: [00:03:06]
# Iteration 679 ETA: [00:03:05]
# Iteration 680 ETA: [00:03:04]
# Iteration 681 ETA: [00:03:02]
# Iteration 682 ETA: [00:03:02]
# Iteration 683 ETA: [00:03:00]
# Iteration 684 ETA: [00:02:59]
# Iteration 685 ETA: [00:02:57]
# Iteration 686 ETA: [00:02:56]
# Iteration 687 ETA: [00:02:55]
# Iteration 688 ETA: [00:02:55]
# Iteration 689 ETA: [00:02:52]
# Iteration 690 ETA: [00:02:51]
# Iteration 691 ETA: [00:02:50]
# Iteration 692 ETA: [00:02:49]
# Iteration 693 ETA: [00:02:47]
# Iteration 694 ETA: [00:02:47]
# Iteration 695 ETA: [00:02:45]
# Iteration 696 ETA: [00:02:44]
# Iteration 697 ETA: [00:02:42]
# Iteration 698 ETA: [00:02:41]
# Iteration 699 ETA: [00:02:40]
# Iteration 700 ETA: [00:02:38]
# Iteration 701 ETA: [00:02:37]
# Iteration 702 ETA: [00:02:36]
# Iteration 703 ETA: [00:02:35]
# Iteration 704 ETA: [00:02:33]
# Iteration 705 ETA: [00:02:32]
# Iteration 706 ETA: [00:02:31]
# Iteration 707 ETA: [00:02:30]
# Iteration 708 ETA: [00:02:28]
# Iteration 709 ETA: [00:02:27]
# Iteration 710 ETA: [00:02:26]
# Iteration 711 ETA: [00:02:24]
# Iteration 712 ETA: [00:02:23]
# Iteration 713 ETA: [00:02:22]
# Iteration 714 ETA: [00:02:20]
# Iteration 715 ETA: [00:02:19]
# Iteration 716 ETA: [00:02:18]
# Iteration 717 ETA: [00:02:17]
# Iteration 718 ETA: [00:02:15]
# Iteration 719 ETA: [00:02:14]
# Iteration 720 ETA: [00:02:13]
# Iteration 721 ETA: [00:02:11]
# Iteration 722 ETA: [00:02:11]
# Iteration 723 ETA: [00:02:09]
# Iteration 724 ETA: [00:02:08]
# Iteration 725 ETA: [00:02:06]
# Iteration 726 ETA: [00:02:05]
# Iteration 727 ETA: [00:02:04]
# Iteration 728 ETA: [00:02:02]
# Iteration 729 ETA: [00:02:01]
# Iteration 730 ETA: [00:02:01]
# Iteration 731 ETA: [00:01:59]
# Iteration 732 ETA: [00:01:57]
# Iteration 733 ETA: [00:01:56]
# Iteration 734 ETA: [00:01:55]
# Iteration 735 ETA: [00:01:53]
# Iteration 736 ETA: [00:01:52]
# Iteration 737 ETA: [00:01:51]
# Iteration 738 ETA: [00:01:50]
# Iteration 739 ETA: [00:01:48]
# Iteration 740 ETA: [00:01:47]
# Iteration 741 ETA: [00:01:46]
# Iteration 742 ETA: [00:01:45]
# Iteration 743 ETA: [00:01:43]
# Iteration 744 ETA: [00:01:42]
# Iteration 745 ETA: [00:01:41]
# Iteration 746 ETA: [00:01:39]
# Iteration 747 ETA: [00:01:38]
# Iteration 748 ETA: [00:01:37]
# Iteration 749 ETA: [00:01:35]
# Iteration 750 ETA: [00:01:34]
# Iteration 751 ETA: [00:01:34]
# Iteration 752 ETA: [00:01:32]
# Iteration 753 ETA: [00:01:30]
# Iteration 754 ETA: [00:01:29]
# Iteration 755 ETA: [00:01:28]
# Iteration 756 ETA: [00:01:27]
# Iteration 757 ETA: [00:01:25]
# Iteration 758 ETA: [00:01:24]
# Iteration 759 ETA: [00:01:23]
# Iteration 760 ETA: [00:01:21]
# Iteration 761 ETA: [00:01:20]
# Iteration 762 ETA: [00:01:19]
# Iteration 763 ETA: [00:01:17]
# Iteration 764 ETA: [00:01:16]
# Iteration 765 ETA: [00:01:15]
# Iteration 766 ETA: [00:01:14]
# Iteration 767 ETA: [00:01:12]
# Iteration 768 ETA: [00:01:11]
# Iteration 769 ETA: [00:01:10]
# Iteration 770 ETA: [00:01:09]
# Iteration 771 ETA: [00:01:07]
# Iteration 772 ETA: [00:01:06]
# Iteration 773 ETA: [00:01:05]
# Iteration 774 ETA: [00:01:04]
# Iteration 775 ETA: [00:01:02]
# Iteration 776 ETA: [00:01:01]
# Iteration 777 ETA: [00:01:00]
# Iteration 778 ETA: [00:00:58]
# Iteration 779 ETA: [00:00:57]
# Iteration 780 ETA: [00:00:56]
# Iteration 781 ETA: [00:00:54]
# Iteration 782 ETA: [00:00:53]
# Iteration 783 ETA: [00:00:52]
# Iteration 784 ETA: [00:00:51]
# Iteration 785 ETA: [00:00:49]
# Iteration 786 ETA: [00:00:48]
# Iteration 787 ETA: [00:00:47]
# Iteration 788 ETA: [00:00:46]
# Iteration 789 ETA: [00:00:44]
# Iteration 790 ETA: [00:00:43]
# Iteration 791 ETA: [00:00:42]
# Iteration 792 ETA: [00:00:40]
# Iteration 793 ETA: [00:00:39]
# Iteration 794 ETA: [00:00:38]
# Iteration 795 ETA: [00:00:37]
# Iteration 796 ETA: [00:00:36]
# Iteration 797 ETA: [00:00:34]
# Iteration 798 ETA: [00:00:33]
# Iteration 799 ETA: [00:00:31]
# Iteration 800 ETA: [00:00:30]
# Iteration 801 ETA: [00:00:29]
# Iteration 802 ETA: [00:00:28]
# Iteration 803 ETA: [00:00:26]
# Iteration 804 ETA: [00:00:25]
# Iteration 805 ETA: [00:00:24]
# Iteration 806 ETA: [00:00:22]
# Iteration 807 ETA: [00:00:21]
# Iteration 808 ETA: [00:00:20]
# Iteration 809 ETA: [00:00:19]
# Iteration 810 ETA: [00:00:18]
# Iteration 811 ETA: [00:00:16]
# Iteration 812 ETA: [00:00:15]
# Iteration 813 ETA: [00:00:14]
# Iteration 814 ETA: [00:00:12]
# Iteration 815 ETA: [00:00:11]
# Iteration 816 ETA: [00:00:10]
# Iteration 817 ETA: [00:00:08]
# Iteration 818 ETA: [00:00:07]
# Iteration 819 ETA: [00:00:06]
# Iteration 820 ETA: [00:00:05]
# Iteration 821 ETA: [00:00:03]
# Iteration 822 ETA: [00:00:02]
# Iteration 823 ETA: [00:00:01]
# Iteration 824 ETA: [00:00:00]

# %%
order_0 = torch.cat(order_0, dim=0)
orders_1_and_2 = torch.cat(orders_1_and_2, dim=0)

order_0 = order_0.cpu().numpy()
orders_1_and_2 = orders_1_and_2.cpu().numpy()

# %%
order_0 = order_0.reshape((n_molecules, -1))
orders_1_and_2 = orders_1_and_2.reshape((n_molecules, -1))

# %%
"""basename = 'qm7_L_{}_J_{}_sigma_{}_MNO_{}_powers_{}.npy'.format(
        L, J, sigma, (M, N, O), integral_powers)"""
basename = 'traindataset_L_{}_J_{}_sigma_{}_MNO_{}_powers_{}.npy'.format(
        L, J, sigma, (M, N, O), integral_powers)

# cache_dir = get_cache_dir("qm7/experiments")
save_dir = "save"

filename = os.path.join(save_dir, 'order_0_' + basename)
np.save(filename, order_0)

filename = os.path.join(save_dir, 'orders_1_and_2' + basename)
np.save(filename, orders_1_and_2)

# %%
scattering_coef = np.concatenate([order_0, orders_1_and_2], axis=1)

# %%
"""qm7 = fetch_qm7()
target = qm7['energies']"""

# %%
# n_folds = 5
n_folds = 3

P = np.random.permutation(n_molecules).reshape((n_folds, -1))

cross_val_folds = []

for i_fold in range(n_folds):
    fold = (np.concatenate(P[np.arange(n_folds) != i_fold], axis=0),
            P[i_fold])
    cross_val_folds.append(fold)

# %%
alphas = 10.0 ** (-np.arange(1, 10))
for i, alpha in enumerate(alphas):
    scaler = preprocessing.StandardScaler()
    ridge = linear_model.Ridge(alpha=alpha)

    regressor = pipeline.make_pipeline(scaler, ridge)

    target_prediction = model_selection.cross_val_predict(regressor,
            X=scattering_coef, y=target, cv=cross_val_folds)

    MAE = np.mean(np.abs(target_prediction - target))
    RMSE = np.sqrt(np.mean((target_prediction - target) ** 2))

    print('Ridge regression, alpha: {}, MAE: {}, RMSE: {}'.format(
        alpha, MAE, RMSE))
# Out:
# Ridge regression, alpha: 0.1, MAE: 5.507477006220774, RMSE: 6.988796081317489
# Ridge regression, alpha: 0.01, MAE: 5.345406858969104, RMSE: 6.832243762946825
# /home/n7student/miniforge3/envs/env_tensorboard/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:215: LinAlgWarning: Ill-conditioned matrix (rcond=3.91001e-09): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# /home/n7student/miniforge3/envs/env_tensorboard/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:215: LinAlgWarning: Ill-conditioned matrix (rcond=3.8376e-09): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# /home/n7student/miniforge3/envs/env_tensorboard/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:215: LinAlgWarning: Ill-conditioned matrix (rcond=4.21781e-09): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# Ridge regression, alpha: 0.001, MAE: 5.284156123051306, RMSE: 6.8373216141688635
# Ridge regression, alpha: 0.0001, MAE: 5.277232745983461, RMSE: 6.868797326387201
# Ridge regression, alpha: 1e-05, MAE: 5.27243517496313, RMSE: 6.84576045460623
# Ridge regression, alpha: 1e-06, MAE: 5.254580659655956, RMSE: 6.7957173526267765
# Ridge regression, alpha: 1e-07, MAE: 5.235566034629851, RMSE: 6.753471198764981
# Ridge regression, alpha: 1e-08, MAE: 5.233941947471445, RMSE: 6.749647209742278
# Ridge regression, alpha: 1e-09, MAE: 5.2338631053661935, RMSE: 6.75398942074925

# %%
# Charger et préparer les données de test
test_positions = []
test_charges = []

# Lister tous les fichiers .xyz dans le dossier test
test_files = sorted(os.listdir('../data/atoms/test'))
test_ids = [int(f.split('_')[1].split('.')[0]) for f in test_files]  # Extraire les IDs

# Lire tous les fichiers .xyz de test
for xyz_file in test_files:
    xyz_path = os.path.join('../data/atoms/test', xyz_file)
    atoms = read(xyz_path)
    
    # Obtenir les positions et numéros atomiques
    coords = atoms.get_positions()
    atomic_numbers = atoms.get_atomic_numbers()
    
    # Padding pour avoir une taille fixe
    padded_coords = np.zeros((max_atoms, 3))
    padded_charges = np.zeros(max_atoms)
    
    n_atoms = len(coords)
    padded_coords[:n_atoms] = coords
    padded_charges[:n_atoms] = atomic_numbers
    
    test_positions.append(padded_coords)
    test_charges.append(padded_charges)

# Convertir en arrays numpy
test_pos = np.array(test_positions)
test_full_charges = np.array(test_charges)
n_test_molecules = len(test_pos)

# Appliquer la même normalisation que pour les données d'entraînement
test_pos = test_pos * delta / min_dist

# Calculer les coefficients de scattering pour les données de test
test_order_0 = []
test_orders_1_2 = []

for i in range(0, n_test_molecules, batch_size):
    end = min(i + batch_size, n_test_molecules)
    pos_batch = test_pos[i:end]
    charges_batch = test_full_charges[i:end]
    
    # Calculer les valence charges
    mask = charges_batch <= 2
    val_batch = charges_batch * mask
    mask = np.logical_and(charges_batch > 2, charges_batch <= 10)
    val_batch += (charges_batch - 2) * mask
    mask = np.logical_and(charges_batch > 10, charges_batch <= 18)
    val_batch += (charges_batch - 10) * mask
    
    # Calculer les descripteurs comme pour l'entraînement
    full_density = generate_weighted_sum_of_gaussians(grid, pos_batch, charges_batch, sigma)
    full_density = torch.from_numpy(full_density).to(device).float()
    
    val_density = generate_weighted_sum_of_gaussians(grid, pos_batch, val_batch, sigma)
    val_density = torch.from_numpy(val_density).to(device).float()
    
    core_density = full_density - val_density
    
    # Calculer les coefficients
    full_0 = TorchBackend3D.compute_integrals(full_density, integral_powers)
    full_s = scattering(full_density)
    
    val_0 = TorchBackend3D.compute_integrals(val_density, integral_powers)
    val_s = scattering(val_density)
    
    core_0 = TorchBackend3D.compute_integrals(core_density, integral_powers)
    core_s = scattering(core_density)
    
    # Empiler les coefficients
    batch_0 = torch.stack((full_0, val_0, core_0), dim=-1)
    batch_s = torch.stack((full_s, val_s, core_s), dim=-1)
    
    test_order_0.append(batch_0.cpu())
    test_orders_1_2.append(batch_s.cpu())

# Concatener tous les batches
test_order_0 = torch.cat(test_order_0, dim=0).numpy()
test_orders_1_2 = torch.cat(test_orders_1_2, dim=0).numpy()

# Reshape comme pour l'entraînement
test_order_0 = test_order_0.reshape((n_test_molecules, -1))
test_orders_1_2 = test_orders_1_2.reshape((n_test_molecules, -1))

# Concaténer les descripteurs
test_scattering_coef = np.concatenate([test_order_0, test_orders_1_2], axis=1)

# Entraîner le modèle final sur toutes les données d'entraînement
final_scaler = preprocessing.StandardScaler()
final_ridge = linear_model.Ridge(alpha=0.1)  # Utiliser le meilleur alpha trouvé
final_model = pipeline.make_pipeline(final_scaler, final_ridge)
final_model.fit(scattering_coef, target)

# Faire les prédictions sur les données de test
test_predictions = final_model.predict(test_scattering_coef)

# Créer et sauvegarder le fichier de prédictions
predictions_df = pd.DataFrame({
    'id': test_ids,
    'energy': test_predictions
})
predictions_df.to_csv('../data/energies/test_pred_scattering.csv', index=False)
print("Prédictions sauvegardées dans test_pred.csv")
# Out:
# Prédictions sauvegardées dans test_pred.csv
# /home/n7student/miniforge3/envs/env_tensorboard/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:215: LinAlgWarning: Ill-conditioned matrix (rcond=4.94015e-08): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
